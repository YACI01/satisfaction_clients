# %%
from elasticsearch import Elasticsearch, helpers
import csv

# Connexion au cluster Elasticsearch
es = Elasticsearch(hosts="http://localhost:9200")

# Nom de l'index
index_name = "reviews"

# Mapping pour l'index
mapping = {
    "mappings": {
        "_meta": {
            "created_by": "yaya"
        },
        "properties": {
            "Company": {"type": "keyword"},
            "Customer": {"type": "keyword"},
            "Date_experience": {"type": "date", "format": "yyyy-MM-dd"},
            "Date_reply": {"type": "date", "format": "yyyy-MM-dd"},
            "Date_review": {"type": "date", "format": "yyyy-MM-dd"},
            "Response_time":{"type": "long"},
            "Experience": {"type": "keyword"},
            "Language": {"type": "keyword"},
            "Number_review": {"type": "long"},
            "Rating": {"type": "long"},
            "Reply": {"type": "keyword"},
            "Status": {"type": "keyword"},
            "Title": {"type": "keyword"},
            "document_id": {"type": "keyword"}
        }
    }
}

def create_elasticsearch_index():
    # Index des avis clients
    index_name = "reviews"
    # Créer l'index avec le mapping (you can skip this if the index already exists)
    if not es.indices.exists(index=index_name):
        es.indices.create(index=index_name, body=mapping)

    # Lecture du fichier CSV et correction des champs vides
    documents = read_csv("../data/processed/reviews.csv")

    # Insérer les documents en vrac dans Elasticsearch
    bulk_insert_documents(documents, index_name)

    # Vérification des documents insérés
    verify_inserted_documents(index_name)

    # Requête pour obtenir les 5 mots clés positifs
    positive_words_aggregation(index_name)

    # Recherche des mots les plus récurrents dans les commentaires négatifs
    negative_words_aggregation(index_name)

    # Requête d'agrégation pour obtenir des statistiques sur le champ "Rating"
    rating_aggregation(index_name)

    # Liste des entreprises avec le plus de commentaires négatifs
    negative_reviews_by_company(index_name)

    # Le nombre de commentaires non répondues par les entreprises
    no_reply_comments_by_company(index_name)

    # Classement des entreprises selon leur note moyenne
    companies_by_average_rating(index_name)

    # Statuts des commentateurs
    reviewer_statuses(index_name)

    # Taux de No Reply et délai de réponse moyen
    no_reply_percentage_and_average_response_time(index_name)

def read_csv(csv_path):
    documents = []
    with open(csv_path, encoding="utf-8") as f:
        reader = csv.DictReader(f)
        for idx, row in enumerate(reader):
            if "" in row:
                row["document_id"] = str(idx)  # Ajout de l'ID du document
                for key in list(row.keys()):
                    if key == "":
                        row.pop(key)  # Suppression des champs avec des clés vides
                documents.append(row)
    return documents

def bulk_insert_documents(documents, index_name):
    try:
        response = helpers.bulk(es, documents, index=index_name)
        print("Documents insérés avec succès :", response)
    except helpers.BulkIndexError as e:
        print("Erreur lors de l'insertion des documents :")
        for err in e.errors:
            print("Erreur :", err)

def verify_inserted_documents(index_name):
    result = es.search(index=index_name, size=5)
    for hit in result["hits"]["hits"]:
        print(hit["_source"])

def search_documents(index_name, query):
    result = es.search(index=index_name, body=query)
    for hit in result["hits"]["hits"]:
        print(hit["_source"])

def positive_words_aggregation(index_name):
    query = {
        "query": {
            "match_all": {}
        },
        "aggs": {
            "positive_words": {
                "terms": {
                    "field": "Experience",
                    "size": 5,
                    "min_doc_count": 5
                },
                "aggs": {
                    "rating_filter": {
                        "filter": {
                            "range": {
                                "Rating": {
                                    "gte": 5,
                                    "lte": 5
                                }
                            }
                        }
                    }
                }
            }
        }
    }
    search_documents(index_name, query)

def negative_words_aggregation(index_name):
    query = {
        "query": {
            "match_all": {}
        },
        "aggs": {
            "negative_words": {
                "terms": {
                    "field": "Title",
                    "size": 3,
                    "min_doc_count": 10
                },
                "aggs": {
                    "rating_filter": {
                        "filter": {
                            "range": {
                                "Rating": {
                                    "gte": 1,
                                    "lte": 1
                                }
                            }
                        }
                    }
                }
            }
        }
    }
    search_documents(index_name, query)

def rating_aggregation(index_name):
    query = {
        "size": 0,
        "aggs": {
            "value_count": {
                "value_count": {
                    "field": "Rating"
                }
            },
            "rating_stats": {
                "stats": {
                    "field": "Rating"
                }
            },
            "extended_ratings_stats": {
                "extended_stats": {
                    "field": "Rating"
                }
            }
        }
    }
    result = es.search(index=index_name, body=query)

    # Afficher les résultats de l'agrégation
    aggregations = result.get("aggregations", {})
    value_count = aggregations.get("value_count", {})
    rating_stats = aggregations.get("rating_stats", {})
    extended_ratings_stats = aggregations.get("extended_ratings_stats", {})

    print("Nombre total de valeurs de rating:", value_count.get("value", 0))
    print("Statistiques de rating:")
    print("    Minimum:", rating_stats.get("min", 0))
    print("    Maximum:", rating_stats.get("max", 0))
    print("    Moyenne:", rating_stats.get("avg", 0))
    print("    Somme:", rating_stats.get("sum", 0))
    print("    Écart-type:", extended_ratings_stats.get("std_deviation", 0))

def negative_reviews_by_company(index_name):
    query = {
        "query": {
            "match_all": {}
        },
        "sort": [
            {
                "Rating": {
                    "order": "asc"  # Tri ascendant (du plus bas au plus haut)
                }
            }
        ]
    }
    result = es.search(index=index_name, body=query)

    negative_reviews = []
    for hit in result["hits"]["hits"]:
        rating = int(hit["_source"]["Rating"])  # Convertir la note en entier
        if rating < 3:  # Supposons que 1 à 2 sont considérés comme des notes négatives
            negative_reviews.append(hit["_source"]["Company"])

    company_count = Counter(negative_reviews)
    sorted_companies = sorted(company_count.items(), key=lambda x: x[1], reverse=True)

    for company, count in sorted_companies[:6]:
        print(f"Entreprise : {company}, Nombre de commentaires négatifs : {count}")

def no_reply_comments_by_company(index_name):
    result = es.search(index=index_name, 
        body={
            "query": {
                "match": {
                    "Reply": {
                        "query": "No Reply"
                    }
                }
            },
            "aggs": {
                "companies": {
                    "terms": {
                        "field": "Company",
                        "size": 10
                    }
                }
            }
        })

    companies = result["aggregations"]["companies"]["buckets"]

    for company in companies:
        print(f"Entreprise : {company['key']} - Nombre de No Reply : {company['doc_count']}")

def companies_by_average_rating(index_name):
    query = {
        "aggs": {
            "companies": {
                "terms": {
                    "field": "Company"
                },
                "aggs": {
                    "average_rating": {
                        "avg": {
                            "field": "Rating"
                        }
                    }
                }
            }
        }
    }
    result = es.search(index=index_name, body=query)

    companies = result["aggregations"]["companies"]["buckets"]
    companies.sort(key=lambda company: company["average_rating"]["value"], reverse=False)

    for company in companies:
        average_ratings = round(company['average_rating']['value'], 2)
        print(f"Entreprise : {company['key']} - Note moyenne : {average_ratings}")

def reviewer_statuses(index_name):
    query = {
        "aggs": {
            "statuses": {
                "terms": {
                    "field": "Status"
                }
            }
        }
    }
    result = es.search(index=index_name, body=query)

    statuses = result["aggregations"]["statuses"]["buckets"]

    for status in statuses:
        print(f"Status : {status['key']} - Nombre de commentateurs : {status['doc_count']}")

def no_reply_percentage_and_average_response_time(index_name):
    query = {
        "query": {
            "match": {
                "Reply": "No Reply"
            }
        },
        "aggs": {
            "total_no_reply": {
                "value_count": {
                    "field": "Reply"
                }
            },
            "companies": {
                "terms": {
                    "field": "Company"
                },
                "aggs": {
                    "number_of_no_reply": {
                        "value_count": {
                            "field": "Reply"
                        }
                    }
                }
            }
        }
    }

    result = es.search(index=index_name, body=query)
    total_no_reply = result["aggregations"]["total_no_reply"]["value"]
    companies = result["aggregations"]["companies"]["buckets"]

    for company in companies:
        number_of_no_reply = company["number_of_no_reply"]["value"]
        percentage = (number_of_no_reply / total_no_reply) * 100
        print(f"Entreprise : {company['key']} - Nombre de No Reply : {number_of_no_reply} - Taux de No Reply : {percentage:.2f}%")

def average_response_time_by_company(index_name):
    query = {
        "aggs": {
            "companies": {
                "terms": {
                    "field": "Company"
                },
                "aggs": {
                    "average_day": {
                        "avg": {
                            "field": "Response_time"
                        }
                    }
                }
            }
        }
    }
    result = es.search(index=index_name, body=query)

    companies = result["aggregations"]["companies"]["buckets"]
    companies.sort(key=lambda company: company["average_day"]["value"], reverse=False)

    for company in companies:
        average_days = round(company['average_day']['value'], 2)
        print(f"Entreprise : {company['key']} - Délai de réponse moyen : {average_days}")

if __name__ == "__main__":
    create_elasticsearch_index()
# Out:
# Error during document insertion:
# Error: {'index': {'_index': 'bdd_test', '_id': 'shemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '0', 'Company': 'Younited Credit', 'Customer': 'M françois GUYOT', 'Number_review': '2', 'Language': 'FR', 'Title': 'SUPER SOCIETE DE CREDITS TRES REACTIVE…', 'Date_review': '2023-07-28 06:28:34', 'Reply': 'No Reply', 'Date_reply': '2023-07-28 06:28:34', 'Rating': '5', 'Status': 'Verified', 'Experience': 'SUPER SOCIETE DE CREDITS TRES REACTIVE…SUPER SOCIETE DE CREDITS TRES REACTIVE sans problêmes merci pour votre pret accorde avec le moins d administratif possible', 'Date_experience': '2023-07-20 00:00:00', 'document_id': '0'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'sxemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '1', 'Company': 'Younited Credit', 'Customer': 'Les parisiens', 'Number_review': '2', 'Language': 'FR', 'Title': 'Simple et efficace !', 'Date_review': '2023-07-28 17:28:34', 'Reply': 'No Reply', 'Date_reply': '2023-07-28 17:28:34', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Simple et efficace !', 'Date_experience': '2023-07-19 00:00:00', 'document_id': '1'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'tBemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '2', 'Company': 'Younited Credit', 'Customer': 'STEPHANIE RENOUX', 'Number_review': '3', 'Language': 'FR', 'Title': 'Simple rapide et efficace !!', 'Date_review': '2023-07-21 00:00:00', 'Reply': 'Bonjour,Nous vous remercions d’avoir pris le temps de nous laisser un message et sommes ravis de lire que vous êtes pleinement satisfait de votre expérience Younited.Nous vous remercions une nouvelle fois pour votre confiance.Excellente journée,Alexandra', 'Date_reply': '2023-07-24 06:28:42', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Simple rapide et efficace !!', 'Date_experience': '2023-07-11 00:00:00', 'document_id': '2'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'tRemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '3', 'Company': 'Younited Credit', 'Customer': 'VERONIQUE', 'Number_review': '1', 'Language': 'FR', 'Title': 'TOP ++', 'Date_review': '2023-07-25 06:28:34', 'Reply': 'Bonjour,Nous vous remercions d’avoir pris le temps de nous laisser un message et sommes ravis de lire que vous êtes pleinement satisfait de votre expérience Younited.Nous vous remercions une nouvelle fois pour votre confiance.Excellente journée,Alexandra', 'Date_reply': '2023-07-26 06:28:42', 'Rating': '5', 'Status': 'Verified', 'Experience': "TOP ++Efficacité et rapidité d'instruction TopJe recommande", 'Date_experience': '2023-07-19 00:00:00', 'document_id': '3'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'themkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '4', 'Company': 'Younited Credit', 'Customer': 'Sall', 'Number_review': '3', 'Language': 'FR', 'Title': 'Procedure top', 'Date_review': '2023-05-30 00:00:00', 'Reply': "Bonjour,\xa0Nous vous remercions pour votre commentaire et sommes navrés de lire que vous n'êtes pas pleinement satisfait de votre expérience Younited.Le taux d’intérêt dépend du montant emprunté, de la durée, et de votre situation personnelle que vous avez renseigné lors de la simulation de votre demande crédit.Chez Younited, nous nous efforçons de proposer des financements à des taux compétitifs afin de pouvoir accompagner tous nos clients dans leurs projets.\xa0Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited.Excellente journée,Tracy", 'Date_reply': '2023-05-31 00:00:00', 'Rating': '4', 'Status': 'Verified', 'Experience': 'Procedure topProcedure top, simple et rapide.Tt est nickel. A part les interets qui sont élevés', 'Date_experience': '2023-05-21 00:00:00', 'document_id': '4'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'txemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '5', 'Company': 'Younited Credit', 'Customer': 'Soso ', 'Number_review': '2', 'Language': 'FR', 'Title': 'Younited une procédure simple', 'Date_review': '2023-02-25 00:00:00', 'Reply': 'Bonjour,Nous vous remercions pour ce commentaire\u202fpositif. En espérant que vous puissiez recommander Younited auprès de votre entourage.Excellente journée,Amori', 'Date_reply': '2023-02-27 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Younited une procédure simpleYounited permet une alternative qui facilite la vie. La procédure est simple et plutôt rapide.', 'Date_experience': '2023-02-19 00:00:00', 'document_id': '5'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'uBemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '6', 'Company': 'Younited Credit', 'Customer': 'Duval', 'Number_review': '9', 'Language': 'FR', 'Title': 'Rapide efficace simple un pur bonheur…', 'Date_review': '2022-11-28 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,Audrey', 'Date_reply': '2022-11-30 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Rapide efficace simple un pur bonheur…Rapide efficace simple un pur bonheur les fonds à disposition à la date prévue respect du beau boulot', 'Date_experience': '2022-11-28 00:00:00', 'document_id': '6'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'uRemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '7', 'Company': 'Younited Credit', 'Customer': 'Michel Lafrechoux', 'Number_review': '5', 'Language': 'FR', 'Title': 'Entire satisfaction', 'Date_review': '2022-11-23 00:00:00', 'Reply': "Hello,Thank you for taking the time to leave us a message.We invite you to leave a review on your country's Trustpilot pageExcellent day,Audrey", 'Date_reply': '2022-11-30 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Entire satisfactionYounited credit gave me the possibility to get a loan relatively rapid.All the people via phone were very efficient and disponible.I have a real good feeling from YounitedThanks', 'Date_experience': '2022-11-18 00:00:00', 'document_id': '7'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'uhemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '8', 'Company': 'Younited Credit', 'Customer': 'Lazarus Jamison', 'Number_review': '1', 'Language': 'MW', 'Title': 'I am yet to confirm the efficiency and…', 'Date_review': '2023-05-06 00:00:00', 'Reply': 'Bonjour,Nous vous remercions d’avoir pris le temps de nous laisser un message et sommes ravis de lire que vous êtes pleinement satisfait de votre expérience Younited.Nous vous remercions une nouvelle fois pour votre confiance.Excellente journée,Alexandra', 'Date_reply': '2023-05-10 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'I am yet to confirm the efficiency and…I am yet to confirm the efficiency and the effectiveness of the Younite professionalism in processing loans. i have just applied recently.', 'Date_experience': '2023-04-06 00:00:00', 'document_id': '8'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'uxemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '9', 'Company': 'Younited Credit', 'Customer': 'Jean-Paul', 'Number_review': '1', 'Language': 'FR', 'Title': 'Tout en simple  et facile', 'Date_review': '2023-07-16 00:00:00', 'Reply': 'Bonjour,Nous vous remercions d’avoir pris le temps de nous laisser un message et sommes ravis de lire que vous êtes pleinement satisfait de votre expérience Younited.Nous vous remercions une nouvelle fois pour votre confiance.Excellente journée,Diane', 'Date_reply': '2023-07-17 00:00:00', 'Rating': '4', 'Status': 'Verified', 'Experience': 'Tout en simple  et facile', 'Date_experience': '2023-07-10 00:00:00', 'document_id': '9'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'vBemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '10', 'Company': 'Younited Credit', 'Customer': 'morris', 'Number_review': '1', 'Language': 'FR', 'Title': 'LA DEMARCHE INTERNET EST SIMPLE ET…', 'Date_review': '2023-06-18 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,\xa0Rekia', 'Date_reply': '2023-06-19 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'LA DEMARCHE INTERNET EST SIMPLE ET…LA DEMARCHE INTERNET EST SIMPLE ET EFFICACE', 'Date_experience': '2023-06-05 00:00:00', 'document_id': '10'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'vRemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '11', 'Company': 'Younited Credit', 'Customer': 'Diego', 'Number_review': '2', 'Language': 'FR', 'Title': "Grace a Younited Credit j'ai pu regeler…", 'Date_review': '2023-05-03 00:00:00', 'Reply': 'Bonjour,Nous vous remercions d’avoir pris le temps de nous laisser un message et sommes ravis de lire que vous êtes pleinement satisfait de votre expérience Younited.Nous vous remercions une nouvelle fois pour votre confiance.Excellente journée,Alexandra', 'Date_reply': '2023-05-03 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': "Grace a Younited Credit j'ai pu regeler…Grace a Younited Credit j'ai pu regeler mon probleme, merci ennormement pour la rapidité et profesionnalisme!!", 'Date_experience': '2023-04-24 00:00:00', 'document_id': '11'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'vhemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '12', 'Company': 'Younited Credit', 'Customer': 'THOMAS', 'Number_review': '1', 'Language': 'FR', 'Title': 'Nickel ,rapide et efficace', 'Date_review': '2023-07-15 00:00:00', 'Reply': 'Bonjour,Nous vous remercions pour ce commentaire\u202fpositif. En espérant que vous puissiez recommander Younited auprès de votre entourage.Excellente journée,Diane', 'Date_reply': '2023-07-17 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Nickel ,rapide et efficace', 'Date_experience': '2023-07-09 00:00:00', 'document_id': '12'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'vxemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '13', 'Company': 'Younited Credit', 'Customer': 'Maryse Cabanes', 'Number_review': '3', 'Language': 'FR', 'Title': 'Au top!', 'Date_review': '2022-11-24 00:00:00', 'Reply': "Bonjour,Nous vous remercions d'avoir pris le temps de nous laisser un message.Nous sommes ravis d'avoir pu vous accompagner dans votre projet.Excellente journée,Diane", 'Date_reply': '2022-11-25 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Au top!La demande en ligne hyper simple!L’accord sous 24h!Les fonds sous 8 j environ .Au top !Merci', 'Date_experience': '2022-11-09 00:00:00', 'document_id': '13'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'wBemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '14', 'Company': 'Younited Credit', 'Customer': 'Nathalie', 'Number_review': '1', 'Language': 'FR', 'Title': 'Rapide', 'Date_review': '2023-06-23 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,Amori', 'Date_reply': '2023-06-26 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'RapideRapide, simple et efficace', 'Date_experience': '2023-06-14 00:00:00', 'document_id': '14'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'wRemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '15', 'Company': 'Younited Credit', 'Customer': 'cliente', 'Number_review': '1', 'Language': 'FR', 'Title': 'Tres simple', 'Date_review': '2023-03-01 00:00:00', 'Reply': "Bonjour,Nous sommes navrés de lire que vous n'êtes pas pleinement satisfait de votre expérience Younited. Nous tenons à vous informer que l’assurance est facultative lors de votre demande et résiliable à tout moment tout au long de la vie du crédit.Pour rappel, cette assurance couvre la totalité de votre crédit.\xa0Nous vous remercions pour votre commentaire et le prenons en compte dans le cadre de l’amélioration de notre qualité de service.\xa0Excellente journée,\xa0Tracy", 'Date_reply': '2023-03-01 00:00:00', 'Rating': '4', 'Status': 'Verified', 'Experience': 'Tres simpleTres simple, prix correct mais assurance trop chere', 'Date_experience': '2023-02-19 00:00:00', 'document_id': '15'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'whemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '16', 'Company': 'Younited Credit', 'Customer': 'Auré', 'Number_review': '1', 'Language': 'FR', 'Title': 'Rapide', 'Date_review': '2023-06-12 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,Audrey', 'Date_reply': '2023-06-13 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'RapideRapide, simple et efficace', 'Date_experience': '2023-06-06 00:00:00', 'document_id': '16'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'wxemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '17', 'Company': 'Younited Credit', 'Customer': 'Poumeaud', 'Number_review': '4', 'Language': 'FR', 'Title': 'Rien à redire', 'Date_review': '2022-12-26 00:00:00', 'Reply': "Bonjour,Nous vous remercions d'avoir pris le temps de nous laisser un message.Nous sommes ravis d'avoir pu vous accompagner dans votre projet.Excellente journée,Amori", 'Date_reply': '2022-12-27 00:00:00', 'Rating': '4', 'Status': 'Verified', 'Experience': 'Rien à redireRien à redire, rapide, clair, efficace, pas de délais. Je recommande. Super simple et rapide.', 'Date_experience': '2022-12-04 00:00:00', 'document_id': '17'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'xBemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '18', 'Company': 'Younited Credit', 'Customer': 'cliente', 'Number_review': '1', 'Language': 'FR', 'Title': 'Rapide', 'Date_review': '2023-05-29 00:00:00', 'Reply': 'Bonjour,Nous vous remercions d’avoir pris le temps de nous laisser un message et sommes ravis de lire que vous êtes pleinement satisfait de votre expérience Younited.Nous vous remercions une nouvelle fois pour votre confiance.Excellente journée,Tracy', 'Date_reply': '2023-05-30 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'RapideRapide, simple et efficace', 'Date_experience': '2023-05-23 00:00:00', 'document_id': '18'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'xRemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '19', 'Company': 'Younited Credit', 'Customer': 'cliente', 'Number_review': '1', 'Language': 'FR', 'Title': 'No comment trustable finance', 'Date_review': '2022-11-29 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,Audrey', 'Date_reply': '2022-11-30 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'No comment trustable finance', 'Date_experience': '2022-10-02 00:00:00', 'document_id': '19'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'xhemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '20', 'Company': 'Younited Credit', 'Customer': 'Lysiane', 'Number_review': '4', 'Language': 'FR', 'Title': 'tres simple et rapide .Bon contact .', 'Date_review': '2023-05-14 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,Audrey', 'Date_reply': '2023-05-15 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'tres simple et rapide .Bon contact .', 'Date_experience': '2023-05-08 00:00:00', 'document_id': '20'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'xxemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '21', 'Company': 'Younited Credit', 'Customer': 'Patrick', 'Number_review': '1', 'Language': 'FR', 'Title': 'Simple rapide et facile', 'Date_review': '2023-05-21 00:00:00', 'Reply': 'Bonjour,Nous vous remercions pour ce commentaire\u202fpositif. En espérant que vous puissiez recommander Younited auprès de votre entourage.Excellente journée,Tracy', 'Date_reply': '2023-05-22 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Simple rapide et facile', 'Date_experience': '2023-05-14 00:00:00', 'document_id': '21'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'yBemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '22', 'Company': 'Younited Credit', 'Customer': 'Laurent', 'Number_review': '1', 'Language': 'FR', 'Title': 'Simple et efficient.', 'Date_review': '2023-06-23 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,Amori', 'Date_reply': '2023-06-26 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Simple et efficient.', 'Date_experience': '2023-06-14 00:00:00', 'document_id': '22'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'yRemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '23', 'Company': 'Younited Credit', 'Customer': 'Mustapha DIEDHIOU', 'Number_review': '4', 'Language': 'FR', 'Title': 'Super', 'Date_review': '2023-02-14 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,Audrey', 'Date_reply': '2023-02-15 00:00:00', 'Rating': '4', 'Status': 'Verified', 'Experience': 'SuperSuper.Fonds mis à disposition dans les délais.Super service 👍Merci Younited.', 'Date_experience': '2023-02-08 00:00:00', 'document_id': '23'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'yhemkosBi_rSG5hd_seP', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '24', 'Company': 'Younited Credit', 'Customer': 'Mourad', 'Number_review': '1', 'Language': 'GA', 'Title': 'Younited tient ces engagements. rapide facile. Bonne alternative.', 'Date_review': '2023-06-05 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,Tracy', 'Date_reply': '2023-06-06 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Younited tient ces engagements. rapide facile. Bonne alternative.', 'Date_experience': '2023-05-30 00:00:00', 'document_id': '24'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'yxemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '25', 'Company': 'Younited Credit', 'Customer': 'Client', 'Number_review': '2', 'Language': 'FR', 'Title': 'Simple rapide et efficace', 'Date_review': '2023-05-09 00:00:00', 'Reply': 'Bonjour,Nous vous remercions d’avoir pris le temps de nous laisser un message et sommes ravis de lire que vous êtes pleinement satisfait de votre expérience Younited.Nous vous remercions une nouvelle fois pour votre confiance.Excellente journée,Alexandra', 'Date_reply': '2023-05-10 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Simple rapide et efficace', 'Date_experience': '2023-05-03 00:00:00', 'document_id': '25'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'zBemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '26', 'Company': 'Younited Credit', 'Customer': 'GRÉGORY SERGE JOSEPH', 'Number_review': '1', 'Language': 'FR', 'Title': 'Simple rapide efficace merci beaucoup', 'Date_review': '2023-06-24 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,Amori', 'Date_reply': '2023-06-26 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Simple rapide efficace merci beaucoup', 'Date_experience': '2023-06-18 00:00:00', 'document_id': '26'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'zRemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '27', 'Company': 'Younited Credit', 'Customer': 'cliente', 'Number_review': '1', 'Language': 'FR', 'Title': 'Simple', 'Date_review': '2023-04-19 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,Amori', 'Date_reply': '2023-04-20 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'SimpleSimple, rapide et efficace', 'Date_experience': '2023-04-10 00:00:00', 'document_id': '27'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'zhemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '28', 'Company': 'Younited Credit', 'Customer': 'client', 'Number_review': '2', 'Language': 'FR', 'Title': 'They’re accurate', 'Date_review': '2023-03-14 00:00:00', 'Reply': "Good morning,Thank you for taking the time to leave us a message.We would prefer you leave a review on your country's Trustpilot Younited page.Excellent day,Audrey", 'Date_reply': '2023-03-14 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'They’re accurateThey’re accurate, you guys are good 👌', 'Date_experience': '2022-03-13 00:00:00', 'document_id': '28'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'zxemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '29', 'Company': 'Younited Credit', 'Customer': 'cliente', 'Number_review': '2', 'Language': 'FR', 'Title': 'Tres bon contact', 'Date_review': '2023-06-18 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,\xa0Rekia', 'Date_reply': '2023-06-19 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Tres bon contactA l écoute et bon contact', 'Date_experience': '2023-06-08 00:00:00', 'document_id': '29'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '0BemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '30', 'Company': 'Younited Credit', 'Customer': 'Fedorov', 'Number_review': '1', 'Language': 'FR', 'Title': 'Simple', 'Date_review': '2023-04-03 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,Rekia', 'Date_reply': '2023-04-03 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'SimpleSimple, rapide et efficace', 'Date_experience': '2023-03-27 00:00:00', 'document_id': '30'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '0RemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '31', 'Company': 'Younited Credit', 'Customer': 'LEON', 'Number_review': '1', 'Language': 'FR', 'Title': 'TOP EFFICACE REACTIF', 'Date_review': '2022-11-27 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,Audrey', 'Date_reply': '2022-11-30 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'TOP EFFICACE REACTIF', 'Date_experience': '2022-11-22 00:00:00', 'document_id': '31'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '0hemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '32', 'Company': 'Younited Credit', 'Customer': 'Marianne', 'Number_review': '1', 'Language': 'FR', 'Title': 'Simple et rapide !', 'Date_review': '2023-06-07 00:00:00', 'Reply': 'Bonjour,Nous vous remercions d’avoir pris le temps de nous laisser un message et sommes ravis de lire que vous êtes pleinement satisfait de votre expérience Younited.Nous vous remercions une nouvelle fois pour votre confiance.Excellente journée,Alexandra', 'Date_reply': '2023-06-08 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Simple et rapide !', 'Date_experience': '2023-05-29 00:00:00', 'document_id': '32'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '0xemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '33', 'Company': 'Younited Credit', 'Customer': 'Vincent', 'Number_review': '1', 'Language': 'FR', 'Title': 'Simple et efficace.', 'Date_review': '2023-06-04 00:00:00', 'Reply': 'Bonjour,Nous vous remercions pour ce commentaire\u202fpositif. En espérant que vous puissiez recommander Younited auprès de votre entourage.Excellente journée,Tracy', 'Date_reply': '2023-06-05 00:00:00', 'Rating': '4', 'Status': 'Verified', 'Experience': 'Simple et efficace.', 'Date_experience': '2023-05-29 00:00:00', 'document_id': '33'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '1BemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '34', 'Company': 'Younited Credit', 'Customer': 'joelle', 'Number_review': '1', 'Language': 'FR', 'Title': 'SIMPLE ET  RAPIDE BOITHEAUVILLE', 'Date_review': '2023-06-06 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,Audrey', 'Date_reply': '2023-06-06 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'SIMPLE ET  RAPIDE BOITHEAUVILLESIMPLE ET  RAPIDE', 'Date_experience': '2023-05-31 00:00:00', 'document_id': '34'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '1RemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '35', 'Company': 'Younited Credit', 'Customer': 'cliente', 'Number_review': '1', 'Language': 'FR', 'Title': 'Hyper simple rapide et efficace', 'Date_review': '2023-02-25 00:00:00', 'Reply': 'Bonjour,Nous vous remercions pour ce commentaire\u202fpositif. En espérant que vous puissiez recommander Younited auprès de votre entourage.Excellente journée,Amori', 'Date_reply': '2023-02-27 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Hyper simple rapide et efficace', 'Date_experience': '2023-02-16 00:00:00', 'document_id': '35'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '1hemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '36', 'Company': 'Younited Credit', 'Customer': 'Jawad Benissa', 'Number_review': '2', 'Language': 'FR', 'Title': 'Top very fast and professional', 'Date_review': '2023-04-03 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,Rekia', 'Date_reply': '2023-04-03 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Top very fast and professional', 'Date_experience': '2023-03-23 00:00:00', 'document_id': '36'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '1xemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '37', 'Company': 'Younited Credit', 'Customer': 'SILVIU-ALIN', 'Number_review': '1', 'Language': 'FR', 'Title': 'Super note 10', 'Date_review': '2023-05-18 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,Audrey', 'Date_reply': '2023-05-19 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Super note 10', 'Date_experience': '2023-05-09 00:00:00', 'document_id': '37'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '2BemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '38', 'Company': 'Younited Credit', 'Customer': 'cliente', 'Number_review': '1', 'Language': 'FR', 'Title': 'Explications claire', 'Date_review': '2023-03-08 00:00:00', 'Reply': 'Bonjour,Nous vous remercions pour ce commentaire\u202fpositif. En espérant que vous puissiez recommander Younited auprès de votre entourage.Excellente journée,Amori', 'Date_reply': '2023-03-08 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Explications claireExplications claire, rapidité de mise à disposition des fonds', 'Date_experience': '2023-02-28 00:00:00', 'document_id': '38'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '2RemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '39', 'Company': 'Younited Credit', 'Customer': 'cliente', 'Number_review': '1', 'Language': 'FR', 'Title': 'Rapide efficace', 'Date_review': '2023-02-21 00:00:00', 'Reply': "Bonjour,Nous vous remercions d'avoir pris le temps de nous laisser un message.Nous sommes ravis d'avoir pu vous accompagner dans votre projet.Excellente journée,Amori", 'Date_reply': '2023-02-21 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Rapide efficaceRapide efficace,  service clients ai top', 'Date_experience': '2023-02-15 00:00:00', 'document_id': '39'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '2hemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '40', 'Company': 'Younited Credit', 'Customer': 'BERGER', 'Number_review': '3', 'Language': 'FR', 'Title': 'Excellent contact', 'Date_review': '2022-10-11 00:00:00', 'Reply': 'No Reply', 'Date_reply': '2022-10-11 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Excellent contactExcellent contact, comprehensif et particulierement agreable et quelle rapidite dans la prise de decision...remarquable en tout point.', 'Date_experience': '2022-09-22 00:00:00', 'document_id': '40'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '2xemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '41', 'Company': 'Younited Credit', 'Customer': 'Fabienne', 'Number_review': '2', 'Language': 'FR', 'Title': 'Simple', 'Date_review': '2022-10-12 00:00:00', 'Reply': 'No Reply', 'Date_reply': '2022-10-12 00:00:00', 'Rating': '4', 'Status': 'Verified', 'Experience': 'SimpleAccès à younited simple et efficace, transmission des documents nécessaires facile, réponse rapide.', 'Date_experience': '2022-09-27 00:00:00', 'document_id': '41'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '3BemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '42', 'Company': 'Younited Credit', 'Customer': 'INGRID FLORENCE YVETTE', 'Number_review': '1', 'Language': 'FR', 'Title': 'Rapide et simple', 'Date_review': '2023-05-10 00:00:00', 'Reply': 'Bonjour,Nous vous remercions d’avoir pris le temps de nous laisser un message et sommes ravis de lire que vous êtes pleinement satisfait de votre expérience Younited.Nous vous remercions une nouvelle fois pour votre confiance.Excellente journée,Tracy', 'Date_reply': '2023-05-10 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Rapide et simple', 'Date_experience': '2023-05-04 00:00:00', 'document_id': '42'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '3RemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '43', 'Company': 'Younited Credit', 'Customer': 'e', 'Number_review': '1', 'Language': 'FR', 'Title': 'Simple rapide', 'Date_review': '2022-11-21 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,Audrey', 'Date_reply': '2022-11-22 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Simple rapideSimple , rapide , efficace', 'Date_experience': '2022-11-08 00:00:00', 'document_id': '43'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '3hemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '44', 'Company': 'Younited Credit', 'Customer': 'Céline Marguerite Thérèse', 'Number_review': '1', 'Language': 'FR', 'Title': 'Simple et efficace.', 'Date_review': '2023-05-02 00:00:00', 'Reply': 'Bonjour,Nous vous remercions d’avoir pris le temps de nous laisser un message et sommes ravis de lire que vous êtes pleinement satisfait de votre expérience Younited.Nous vous remercions une nouvelle fois pour votre confiance.Excellente journée,Alexandra', 'Date_reply': '2023-05-03 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Simple et efficace.', 'Date_experience': '2023-04-23 00:00:00', 'document_id': '44'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '3xemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '45', 'Company': 'Younited Credit', 'Customer': 'Madame BOULET', 'Number_review': '2', 'Language': 'FR', 'Title': 'Top crédit', 'Date_review': '2022-11-19 00:00:00', 'Reply': "Bonjour,Nous vous remercions d'avoir pris le temps de nous laisser un message.Nous sommes ravis d'avoir pu vous accompagner dans votre projet.Excellente journée,Diane", 'Date_reply': '2022-11-19 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Top créditRapide et efficace , et simple', 'Date_experience': '2022-11-19 00:00:00', 'document_id': '45'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '4BemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '46', 'Company': 'Younited Credit', 'Customer': 'Client', 'Number_review': '3', 'Language': 'FR', 'Title': 'Simple efficace rapide et contact…', 'Date_review': '2022-10-12 00:00:00', 'Reply': 'No Reply', 'Date_reply': '2022-10-12 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Simple efficace rapide et contact…Simple efficace rapide et contact téléphonique courtois.Ma 3eme expérience positive.Merci', 'Date_experience': '2022-10-12 00:00:00', 'document_id': '46'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '4RemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '47', 'Company': 'Younited Credit', 'Customer': 'cliente', 'Number_review': '1', 'Language': 'FR', 'Title': 'Great experience with fast service and…', 'Date_review': '2022-09-05 00:00:00', 'Reply': 'Bonjour,Nous vous remercions pour ce commentaire positif.Excellente journée,Audrey', 'Date_reply': '2022-09-07 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Great experience with fast service and…Great experience with fast service and no difficult complex exchanges. Will definitely come back when I have a new project planned for our family.', 'Date_experience': '2022-09-05 00:00:00', 'document_id': '47'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': '4hemkosBi_rSG5hd_seQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '48', 'Company': 'Younited Credit', 'Customer': 'Monsieur LIDOREAU', 'Number_review': '4', 'Language': 'FR', 'Title': 'Simple et efficace', 'Date_review': '2023-05-28 00:00:00', 'Reply': 'Bonjour,Merci d’avoir pris le temps de nous faire un retour sur votre expérience auprès de Younited, et sommes ravis de lire que celle-ci s’est bien passée.Nous nous efforçons d’offrir à nos clients un crédit aussi juste, simple et rapide que possible et sommes heureux d’avoir pu vous en faire bénéficier.Excellente journée,Audrey', 'Date_reply': '2023-05-29 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Simple et efficaceAccessible, simplicité, efficacité dans la gestion , merci', 'Date_experience': '2023-05-16 00:00:00', 'document_id': '48'}}}
# ...
# Error: {'index': {'_index': 'bdd_test', '_id': 'khemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '492', 'Company': 'Younited Credit', 'Customer': 'M. CHOFFEY', 'Number_review': '1', 'Language': 'FR', 'Title': 'claire rapide simple', 'Date_review': '2019-02-18 00:00:00', 'Reply': 'Bonjour  Monsieur,Nous sommes ravis de lire que vous êtes pleinement satisfait de votre expérience Younited et sommes heureux de vous compter parmi nos clients.Excellente journée,L’équipe Younited Credit', 'Date_reply': '2019-02-18 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'claire rapide simple', 'Date_experience': '2019-02-18 00:00:00', 'document_id': '480'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'kxemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '493', 'Company': 'Younited Credit', 'Customer': ' NICOLE. N.', 'Number_review': '3', 'Language': 'FR', 'Title': 'Efficace', 'Date_review': '2019-02-14 00:00:00', 'Reply': 'No Reply', 'Date_reply': '2019-02-14 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'EfficaceEfficace, rapide. Merci.', 'Date_experience': '2019-02-14 00:00:00', 'document_id': '481'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'lBemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '494', 'Company': 'Younited Credit', 'Customer': 'gilbert', 'Number_review': '1', 'Language': 'FR', 'Title': 'simple et rapide', 'Date_review': '2019-02-12 00:00:00', 'Reply': 'Bonjour  Monsieur,Nous vous remercions pour ce commentaire positif.Excellente journée, AMOR de l’équipe Younited Credit', 'Date_reply': '2019-02-12 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'simple et rapide', 'Date_experience': '2019-02-12 00:00:00', 'document_id': '482'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'lRemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '495', 'Company': 'Younited Credit', 'Customer': 'Gael', 'Number_review': '4', 'Language': 'FR', 'Title': 'Simple et rapide', 'Date_review': '2019-02-08 00:00:00', 'Reply': 'No Reply', 'Date_reply': '2019-02-08 00:00:00', 'Rating': '4', 'Status': 'Verified', 'Experience': 'Simple et rapide', 'Date_experience': '2019-02-08 00:00:00', 'document_id': '483'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'lhemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '496', 'Company': 'Younited Credit', 'Customer': 'Vincent ', 'Number_review': '1', 'Language': 'FR', 'Title': 'Simple et rapide', 'Date_review': '2019-02-06 00:00:00', 'Reply': "Bonjour  Monsieur, Nous vous remercions d'avoir pris le temps de nous laisser un message. Nous sommes ravis d'avoir pu vous accompagner dans votre trésorerie.Excellente journée, AMOR de l’équipe Younited Credit", 'Date_reply': '2019-02-06 00:00:00', 'Rating': '4', 'Status': 'Verified', 'Experience': 'Simple et rapide', 'Date_experience': '2019-02-06 00:00:00', 'document_id': '484'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'lxemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '497', 'Company': 'Younited Credit', 'Customer': 'Gerardo', 'Number_review': '1', 'Language': 'FR', 'Title': 'excellent', 'Date_review': '2019-02-06 00:00:00', 'Reply': 'No Reply', 'Date_reply': '2019-02-06 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'excellentexcellent, service optimal.', 'Date_experience': '2019-02-06 00:00:00', 'document_id': '485'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'mBemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '498', 'Company': 'Younited Credit', 'Customer': 'Dominique', 'Number_review': '1', 'Language': 'FR', 'Title': 'Rapide', 'Date_review': '2019-02-05 00:00:00', 'Reply': 'Bonjour Madame, Nous vous remercions pour ce commentaire positif.Excellente journée, DIANE DE L’ÉQUIPE Younited Credit', 'Date_reply': '2019-02-05 00:00:00', 'Rating': '4', 'Status': 'Verified', 'Experience': 'RapideRapide facile efficace', 'Date_experience': '2019-02-05 00:00:00', 'document_id': '486'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'mRemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '499', 'Company': 'Younited Credit', 'Customer': 'Madame Alexandra Bianchi', 'Number_review': '2', 'Language': 'FR', 'Title': 'Rapide efficace', 'Date_review': '2019-02-04 00:00:00', 'Reply': 'No Reply', 'Date_reply': '2019-02-04 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': "Rapide efficaceRapide efficace - les interlocuteurs sont d'un grand professionnalisme.", 'Date_experience': '2019-02-04 00:00:00', 'document_id': '487'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'mhemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '500', 'Company': 'Younited Credit', 'Customer': 'patricia', 'Number_review': '1', 'Language': 'FR', 'Title': 'Rapidité', 'Date_review': '2019-02-04 00:00:00', 'Reply': 'Bonjour Madame,Nous vous remercions d’avoir pris le temps de nous laisser un message et sommes ravis de lire que vous être pleinement satisfait de votre expérience Younited.Excellente journée,AMOR de l’équipe Younited Credit', 'Date_reply': '2019-02-04 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'RapiditéSimple rapide', 'Date_experience': '2019-02-04 00:00:00', 'document_id': '488'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'mxemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '501', 'Company': 'Younited Credit', 'Customer': 'SIMON', 'Number_review': '2', 'Language': 'FR', 'Title': 'super credit', 'Date_review': '2019-01-19 00:00:00', 'Reply': 'No Reply', 'Date_reply': '2019-01-19 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'super credit', 'Date_experience': '2019-01-19 00:00:00', 'document_id': '489'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'nBemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '502', 'Company': 'Younited Credit', 'Customer': 'Mils', 'Number_review': '4', 'Language': 'FR', 'Title': 'Simple', 'Date_review': '2018-12-27 00:00:00', 'Reply': 'No Reply', 'Date_reply': '2018-12-27 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'SimpleSimple, rapide et facile', 'Date_experience': '2018-12-27 00:00:00', 'document_id': '490'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'nRemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '503', 'Company': 'Younited Credit', 'Customer': 'Davud du 83', 'Number_review': '1', 'Language': 'FR', 'Title': 'Efficace et rapide', 'Date_review': '2018-12-27 00:00:00', 'Reply': 'Bonjour  Monsieur ,Nous sommes enchantés de vous lire ! Bienvenue chez Younited. Excellente journée, L’équipe Younited Credit', 'Date_reply': '2018-12-28 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Efficace et rapiderapide, efficace, sans question à se poser lors de la constitution du dossier. Bravo !', 'Date_experience': '2018-12-27 00:00:00', 'document_id': '491'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'nhemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '504', 'Company': 'Younited Credit', 'Customer': 'Pierre', 'Number_review': '1', 'Language': 'FR', 'Title': 'Inscription simple et rapide', 'Date_review': '2018-12-27 00:00:00', 'Reply': "Bonjour  Monsieur ,Nous sommes ravis de lire que vous êtes pleinement satisfait de votre expérience Younited et vous remercie d’être fidèle à Younited.Excellente journée et bonne fêtes de fin d'année.L’équipe Younited Credit", 'Date_reply': '2018-12-27 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Inscription simple et rapideInscription simple, rapide et efficace. Tout se fait en ligne sans paperasse ! Je recommande vivement.', 'Date_experience': '2018-12-27 00:00:00', 'document_id': '492'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'nxemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '505', 'Company': 'Younited Credit', 'Customer': 'Hugo Ramses', 'Number_review': '1', 'Language': 'FR', 'Title': 'Excellent', 'Date_review': '2018-12-22 00:00:00', 'Reply': 'No Reply', 'Date_reply': '2018-12-22 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'ExcellentExcellent ,rapid', 'Date_experience': '2018-12-22 00:00:00', 'document_id': '493'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'oBemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '506', 'Company': 'Younited Credit', 'Customer': 'Franck', 'Number_review': '1', 'Language': 'FR', 'Title': 'Simple et rapide', 'Date_review': '2018-12-22 00:00:00', 'Reply': 'No Reply', 'Date_reply': '2018-12-22 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Simple et rapide', 'Date_experience': '2018-12-22 00:00:00', 'document_id': '494'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'oRemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '507', 'Company': 'Younited Credit', 'Customer': 'Alain', 'Number_review': '1', 'Language': 'FR', 'Title': 'Services et communications excellents…', 'Date_review': '2018-12-11 00:00:00', 'Reply': 'Bonjour MonsieurNous vous remercions pour ce bon retour ! Excellente journée, L’équipe Younited Credit', 'Date_reply': '2018-12-11 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Services et communications excellents…Services et communications excellents très rapide je conseil Younited-crédit a 100%', 'Date_experience': '2018-12-11 00:00:00', 'document_id': '495'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'ohemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '508', 'Company': 'Younited Credit', 'Customer': 'Ta', 'Number_review': '1', 'Language': 'FR', 'Title': 'Parfait !!!!', 'Date_review': '2018-12-06 00:00:00', 'Reply': 'No Reply', 'Date_reply': '2018-12-06 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'Parfait !!!!', 'Date_experience': '2018-12-06 00:00:00', 'document_id': '496'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'oxemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '509', 'Company': 'Younited Credit', 'Customer': 'Haïat', 'Number_review': '1', 'Language': 'FR', 'Title': 'EFFICACE', 'Date_review': '2018-12-03 00:00:00', 'Reply': 'Bonjour Madame,Nous sommes enchantés de vous lire ! Bienvenue chez Younited. Excellente journée, L’équipe Younited Credit', 'Date_reply': '2018-12-03 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'EFFICACESimple, rapide et efficace. Service de grande qualité. Je recommande sans hésitation. Merci Younited.', 'Date_experience': '2018-12-03 00:00:00', 'document_id': '497'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'pBemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '510', 'Company': 'Younited Credit', 'Customer': 'DENIS', 'Number_review': '1', 'Language': 'FR', 'Title': 'un grand merci a younited credit', 'Date_review': '2018-11-21 00:00:00', 'Reply': 'No Reply', 'Date_reply': '2018-11-21 00:00:00', 'Rating': '5', 'Status': 'Verified', 'Experience': 'un grand merci a younited credit', 'Date_experience': '2018-11-21 00:00:00', 'document_id': '498'}}}
# Error: {'index': {'_index': 'bdd_test', '_id': 'pRemkosBi_rSG5hd_smQ', 'status': 400, 'error': {'type': 'document_parsing_exception', 'reason': '[1:2] failed to parse: field name cannot be an empty string', 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'field name cannot be an empty string'}}, 'data': {'': '511', 'Company': 'Younited Credit', 'Customer': 'David', 'Number_review': '1', 'Language': 'FR', 'Title': 'Bon service pour un credit', 'Date_review': '2018-11-21 00:00:00', 'Reply': 'No Reply', 'Date_reply': '2018-11-21 00:00:00', 'Rating': '4', 'Status': 'Verified', 'Experience': 'Bon service pour un credit', 'Date_experience': '2018-11-21 00:00:00', 'document_id': '499'}}}

# %%
# Define the aggregation query to find negative keywords
query = {
    "query": {
        "match_all": {}
    },
    "aggs": {
        "negative_words": {
            "terms": {
                "field": "Experience.keyword",  # Use '.keyword' for keyword fields
                "size": 5,
                "min_doc_count": 10
            },
            "sort": [
                {
                    "_count": {
                        "order": "desc"  # Sort in descending order (from highest to lowest)
                    }
                }
            ],
            "aggs": {
                "rating_filter": {
                    "filter": {
                        "range": {
                            "Rating": {
                                "gte": 1,
                                "lte": 1
                            }
                        }
                    }
                }
            }
        }
    }
}

# Execute the aggregation query
result = es.search(index=index_name, body=query)

# Retrieve and display the results
negative_words = result["aggregations"]["negative_words"]["buckets"]

for negative_word in negative_words:
    print(f"Negative Keyword: {negative_word['key']} - Occurrences: {negative_word['doc_count']}")
