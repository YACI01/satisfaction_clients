# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def extract_reviews(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    data = []
    
    pagination = soup.find("div", class_="styles_pagination__6VmQv")
    last_page = pagination.find_all("a")[-2].text
    last_page = pd.to_numeric(last_page)
    
    for i in range(1, last_page + 1):
        page_url = url + "?page=" + str(i)
        page_response = requests.get(page_url)
        page_soup = BeautifulSoup(page_response.content, 'html.parser')
        
        reviews = page_soup.find_all("div", class_="styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ")
        
        for review in reviews:
            review_data = {}
            
            review_data["Company"] = soup.find("h1", class_="typography_default__hIMlQ typography_appearance-default__AAY17 title_title__i9V__").span.get_text(strip=True)
            review_data["Customer"] = review.find("span", class_="typography_heading-xxs__QKBS8 typography_appearance-default__AAY17").text
            review_data["Number_review"] = review.find("div", class_="styles_consumerExtraDetails__fxS4S").find("span").text
            review_data["Language"] = review.find("div", class_="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_detailsIcon__Fo_ua")
            review_data["Title"] = review.find("h2", class_="typography_heading-s__f7029 typography_appearance-default__AAY17").text
            review_data["Date_review"] = review.find("div", class_="styles_reviewHeader__iU9Px").time.text
            reply = review.find("div").find("p", class_="typography_body-m__xgxZ_ typography_appearance-default__AAY17 styles_message__shHhX")
            review_data['Reply'] = reply.text if reply else None
            review_data['Date_reply'] = review.find("div", class_="styles_content__Hl2Mi").time.text if reply else None
            review_data["Rating"] = review.find("section", class_="styles_reviewContentwrapper__zH_9M").div["data-service-review-rating"]
            type_element = review.find_next("div", class_="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_detailsIcon__yqwWi")
            review_data["Status"] = type_element.find("span").text if type_element else None
            review_data["Experience Date"] = review.find("div", class_="styles_reviewContent__0Q2Tg").text
            
            data.append(review_data)
    
    df = pd.DataFrame(data)
    return df

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import dateparser
import re
import os
import time

# %%
younited_url = "https://www.trustpilot.com/review/www.younited-credit.com"
df_younited = extract_reviews(younited_url)
#df_younited.to_csv("../data/raw/younited.csv")

# %%
cofidis_url = "https://www.trustpilot.com/review/www.cofidis.fr"
df_cofidis = extract_reviews(cofidis_url)
#df_cofidis.to_csv("../data/raw/cofidis.csv")

# %%
floa_url = "https://www.trustpilot.com/review/www.floabank.fr"
df_floa = extract_reviews(floa_url)
#df_floa.to_csv("../data/raw/floa.csv")

# %%
orange_url = "https://www.trustpilot.com/review/www.orangebank.fr"
df_orange = extract_reviews(orange_url)
#df_orange.to_csv("../data/raw/orange.csv")

# %%
bourso_url = "https://www.trustpilot.com/review/boursorama-banque.com"
df_bourso = extract_reviews(bourso_url)
#df_bourso.to_csv("../data/raw/bourso.csv")

# %%
anytime_url = "https://www.trustpilot.com/review/anyti.me"
df_anytime = extract_reviews(anytime_url)
#df_anytime.to_csv("../data/raw/anytime.csv")

# %%
df_all = pd.concat([df_younited, df_cofidis, df_orange, df_floa, df_bourso, df_anytime], axis=0)

df_all = df_all.reset_index(drop=True)
df_all
# Out:
#               Company                     Customer Number_review  \
# 0     Younited Credit                       Alexis     2 reviews
# 1     Younited Credit                     Exo Saru     3 reviews
# 2     Younited Credit                      Getifra     3 reviews
# 3     Younited Credit                        Duval     9 reviews
# 4     Younited Credit                        Soso      2 reviews
# ...               ...                          ...           ...
# 2438          Anytime                 AMIR TAOUBAS      1 review
# 2439          Anytime             HOCINE TABERKOKT      1 review
# 2440          Anytime  TOTO JOSUE WENCESLAS KOUAME      1 review
# 2441          Anytime                  SHOLA SANNI      1 review
# 2442          Anytime                PATRICE YALAP      1 review
#
#               Language                                   Title   Date_review  \
# 0     [[[], []], [FR]]                       Very good service  Oct 23, 2023
# 1     [[[], []], [FR]]                            Super simple  Aug 24, 2023
# 2     [[[], []], [FR]]         Younited Credit a démontré son…   Aug 5, 2023
# 3     [[[], []], [FR]]  Rapide efficace simple un pur bonheur…  Nov 28, 2022
# 4     [[[], []], [FR]]           Younited une procédure simple  Feb 25, 2023
# ...                ...                                     ...           ...
# 2438  [[[], []], [DE]]                         Service parfait   Mar 3, 2023
# 2439  [[[], []], [FR]]                Excellente communication  May 16, 2022
# 2440  [[[], []], [FR]]                Excellent service client   Mar 8, 2023
# 2441  [[[], []], [FR]]                 Nice job and keep it up  Apr 11, 2022
# 2442  [[[], []], [FR]]                               excellent   Apr 5, 2022
#
#                                                   Reply           Date_reply  \
# 0     Bonjour,Nous sommes enchantés de vous lire et ...         Oct 24, 2023
# 1     Bonjour,Nous vous remercions d’avoir pris le t...         Aug 25, 2023
# 2     Bonjour,Nous vous remercions d’avoir pris le t...          Aug 8, 2023
# 3     Bonjour,Merci d’avoir pris le temps de nous fa...         Nov 30, 2022
# 4     Bonjour,Nous vous remercions pour ce commentai...         Feb 27, 2023
# ...                                                 ...                  ...
# 2438  Bonjour 😁, Merci pour votre super avis ! A trè...          Mar 6, 2023
# 2439  Bonjour 🫶, Merci beaucoup pour l'avis positif ...         May 17, 2022
# 2440  Bonjour Toto Josue, Merci de partager votre av...          Mar 9, 2023
# 2441  Bonjour 😁Merci beaucoup pour cet avis positif....         Apr 13, 2022
# 2442  Bonjour Patrice, Merci pour ce commentaire pos...  Updated Apr 7, 2022
#
#      Rating    Status                                    Experience Date
# 0         5  Verified  Very good serviceDate of experience: October 1...
# 1         5  Verified  Super simpleSuper simple, très rapide, interfa...
# 2         5  Verified  Younited Credit a démontré son…Younited Credit...
# 3         5  Verified  Rapide efficace simple un pur bonheur…Rapide e...
# 4         5  Verified  Younited une procédure simpleYounited permet u...
# ...     ...       ...                                                ...
# 2438      5   Invited  Service parfaitDate of experience: March 02, 2023
# 2439      5   Invited  Excellente communicationDate of experience: Ma...
# 2440      5   Invited  Excellent service clientDate of experience: Ja...
# 2441      5   Invited  Nice job and keep it upDate of experience: Apr...
# 2442      5   Invited  excellentexcellente interventionDate of experi...
#
# [2443 rows x 11 columns]

# %%
df_all["Experience Date"]
# Out:
# 0       Very good serviceDate of experience: October 1...
# 1       Super simpleSuper simple, très rapide, interfa...
# 2       Younited Credit a démontré son…Younited Credit...
# 3       Rapide efficace simple un pur bonheur…Rapide e...
# 4       Younited une procédure simpleYounited permet u...
#                               ...
# 2438    Service parfaitDate of experience: March 02, 2023
# 2439    Excellente communicationDate of experience: Ma...
# 2440    Excellent service clientDate of experience: Ja...
# 2441    Nice job and keep it upDate of experience: Apr...
# 2442    excellentexcellente interventionDate of experi...
# Name: Experience Date, Length: 2443, dtype: object

# %%
df_all.isnull().sum()
# Out:
# Company               0
# Customer              0
# Number_review         0
# Language              3
# Title                 0
# Date_review           0
# Reply              1008
# Date_reply         1008
# Rating                0
# Status               47
# Experience Date       0
# dtype: int64

# %%
df_all[["Number_review", "review"]]= df_all["Number_review"].str.split(" ", n = 1, expand = True)
df_all[["Number_review", "review"]]
# Out:
#      Number_review   review
# 0                2  reviews
# 1                3  reviews
# 2                3  reviews
# 3                9  reviews
# 4                2  reviews
# ...            ...      ...
# 2438             1   review
# 2439             1   review
# 2440             1   review
# 2441             1   review
# 2442             1   review
#
# [2443 rows x 2 columns]

# %%
df_all[["ExperienceDate", "Date_experience"]]= df_all["Experience Date"].str.split(":", n = 1, expand = True)
df_all[["ExperienceDate", "Date_experience"]]
# Out:
#                                          ExperienceDate     Date_experience
# 0                   Very good serviceDate of experience    October 18, 2023
# 1     Super simpleSuper simple, très rapide, interfa...     August 17, 2023
# 2     Younited Credit a démontré son…Younited Credit...       July 27, 2023
# 3     Rapide efficace simple un pur bonheur…Rapide e...   November 28, 2022
# 4     Younited une procédure simpleYounited permet u...   February 19, 2023
# ...                                                 ...                 ...
# 2438                  Service parfaitDate of experience      March 02, 2023
# 2439         Excellente communicationDate of experience        May 16, 2022
# 2440         Excellent service clientDate of experience    January 31, 2023
# 2441          Nice job and keep it upDate of experience      April 11, 2022
# 2442  excellentexcellente interventionDate of experi...      April 05, 2022
#
# [2443 rows x 2 columns]

# %%
df_all[["Experience", "Date"]]= df_all["Experience Date"].str.split("Date", n = 1, expand = True)
df_all['Experience'][2]
# Out:
# 'Younited Credit a démontré son…Younited Credit a démontré son professionnalisme dans le montage de mon dossier de financement. Avec mes sincères remerciements.Cordialement votre.'

# %%
new_df = df_all[["Company", "Customer", "Number_review", "Language", "Title", "Date_review", "Reply", "Date_reply", "Rating", "Status", "Experience", "Date_experience"]]
new_df
# Out:
#               Company                     Customer Number_review  \
# 0     Younited Credit                       Alexis             2
# 1     Younited Credit                     Exo Saru             3
# 2     Younited Credit                      Getifra             3
# 3     Younited Credit                        Duval             9
# 4     Younited Credit                        Soso              2
# ...               ...                          ...           ...
# 2438          Anytime                 AMIR TAOUBAS             1
# 2439          Anytime             HOCINE TABERKOKT             1
# 2440          Anytime  TOTO JOSUE WENCESLAS KOUAME             1
# 2441          Anytime                  SHOLA SANNI             1
# 2442          Anytime                PATRICE YALAP             1
#
#               Language                                   Title   Date_review  \
# 0     [[[], []], [FR]]                       Very good service  Oct 23, 2023
# 1     [[[], []], [FR]]                            Super simple  Aug 24, 2023
# 2     [[[], []], [FR]]         Younited Credit a démontré son…   Aug 5, 2023
# 3     [[[], []], [FR]]  Rapide efficace simple un pur bonheur…  Nov 28, 2022
# 4     [[[], []], [FR]]           Younited une procédure simple  Feb 25, 2023
# ...                ...                                     ...           ...
# 2438  [[[], []], [DE]]                         Service parfait   Mar 3, 2023
# 2439  [[[], []], [FR]]                Excellente communication  May 16, 2022
# 2440  [[[], []], [FR]]                Excellent service client   Mar 8, 2023
# 2441  [[[], []], [FR]]                 Nice job and keep it up  Apr 11, 2022
# 2442  [[[], []], [FR]]                               excellent   Apr 5, 2022
#
#                                                   Reply           Date_reply  \
# 0     Bonjour,Nous sommes enchantés de vous lire et ...         Oct 24, 2023
# 1     Bonjour,Nous vous remercions d’avoir pris le t...         Aug 25, 2023
# 2     Bonjour,Nous vous remercions d’avoir pris le t...          Aug 8, 2023
# 3     Bonjour,Merci d’avoir pris le temps de nous fa...         Nov 30, 2022
# 4     Bonjour,Nous vous remercions pour ce commentai...         Feb 27, 2023
# ...                                                 ...                  ...
# 2438  Bonjour 😁, Merci pour votre super avis ! A trè...          Mar 6, 2023
# 2439  Bonjour 🫶, Merci beaucoup pour l'avis positif ...         May 17, 2022
# 2440  Bonjour Toto Josue, Merci de partager votre av...          Mar 9, 2023
# 2441  Bonjour 😁Merci beaucoup pour cet avis positif....         Apr 13, 2022
# 2442  Bonjour Patrice, Merci pour ce commentaire pos...  Updated Apr 7, 2022
#
#      Rating    Status                                         Experience  \
# 0         5  Verified                                  Very good service
# 1         5  Verified  Super simpleSuper simple, très rapide, interfa...
# 2         5  Verified  Younited Credit a démontré son…Younited Credit...
# 3         5  Verified  Rapide efficace simple un pur bonheur…Rapide e...
# 4         5  Verified  Younited une procédure simpleYounited permet u...
# ...     ...       ...                                                ...
# 2438      5   Invited                                    Service parfait
# 2439      5   Invited                           Excellente communication
# 2440      5   Invited                           Excellent service client
# 2441      5   Invited                            Nice job and keep it up
# 2442      5   Invited                   excellentexcellente intervention
#
#          Date_experience
# 0       October 18, 2023
# 1        August 17, 2023
# 2          July 27, 2023
# 3      November 28, 2022
# 4      February 19, 2023
# ...                  ...
# 2438      March 02, 2023
# 2439        May 16, 2022
# 2440    January 31, 2023
# 2441      April 11, 2022
# 2442      April 05, 2022
#
# [2443 rows x 12 columns]

# %%
new_df.groupby(by="Status").describe()
# Out:
#            Company                              Customer         \
#              count unique              top freq    count unique
# Status
# Invited       1397      6      Orange Bank  733     1397   1290
# Merged         433      1       BoursoBank  433      433    426
# Redirected      18      1         Floabank   18       18     17
# Verified       548      1  Younited Credit  548      548    428
#
#                                   Number_review         ... Rating        \
#                          top freq         count unique  ...    top  freq
# Status                                                  ...
# Invited             Philippe    9          1397     20  ...      5  1135
# Merged                Client    5           433     21  ...      5   369
# Redirected  Peter Mozelewski    2            18      8  ...      5    14
# Verified             cliente   53           548     13  ...      5   472
#
#            Experience                                                  \
#                 count unique                                 top freq
# Status
# Invited          1397   1232                    Simple et rapide   22
# Merged            433    381                    simple et rapide   11
# Redirected         18     18  Rapide et efficace via WhatsApp !!    1
# Verified          548    460                    Simple et rapide   22
#
#            Date_experience
#                      count unique                 top freq
# Status
# Invited               1397    614      April 22, 2022   26
# Merged                 433    327   December 01, 2021    5
# Redirected              18     18    October 31, 2023    1
# Verified               548    443     August 08, 2020    7
#
# [4 rows x 44 columns]

# %%
new_df[["Reply", "Date_reply"]].isna().sum()
# Out:
# Reply         1008
# Date_reply    1008
# dtype: int64

# %%
new_df[["Status"]] = new_df[["Status"]].fillna(method = "ffill")
new_df[["Status"]]
# Out:
# c:\Users\yaya-\anaconda3\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#         Status
# 0     Verified
# 1     Verified
# 2     Verified
# 3     Verified
# 4     Verified
# ...        ...
# 2438   Invited
# 2439   Invited
# 2440   Invited
# 2441   Invited
# 2442   Invited
#
# [2443 rows x 1 columns]

# %%
new_df.isna().sum()
# Out:
# Company               0
# Customer              0
# Number_review         0
# Language              3
# Title                 0
# Date_review           0
# Reply              1008
# Date_reply         1008
# Rating                0
# Status                0
# Experience            0
# Date_experience       0
# dtype: int64

# %%
new_df.dtypes
# Out:
# Company            object
# Customer           object
# Number_review      object
# Language           object
# Title              object
# Date_review        object
# Reply              object
# Date_reply         object
# Rating             object
# Status             object
# Experience         object
# Date_experience    object
# dtype: object

# %%
new_df[["Number_review", "Rating"]] = new_df[["Number_review", "Rating"]].astype("int64")
new_df.dtypes
# Out:
# c:\Users\yaya-\anaconda3\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# Company            object
# Customer           object
# Number_review       int64
# Language           object
# Title              object
# Date_review        object
# Reply              object
# Date_reply         object
# Rating              int64
# Status             object
# Experience         object
# Date_experience    object
# dtype: object

# %%
#! pip install dateparser

# %%
#import pandas as pd
import dateparser

# Convertir les colonnes "Date_review", "Date_reply" et "Date_experience" en dates
new_df["Date_reply"] = new_df["Date_reply"].fillna(new_df["Date_review"])
new_df['Date_review'] = new_df['Date_review'].apply(lambda x: dateparser.parse(x).strftime('%Y-%m-%d') if isinstance(x, str) and dateparser.parse(x) is not None else x)
#new_df['Date_experience'] = new_df['Date_experience'].apply(lambda x: dateparser.parse(x).strftime('%Y-%m-%d') if isinstance(x, str) and dateparser.parse(x) is not None else x)
#new_df['Date_reply'] = new_df['Date_reply'].apply(lambda x: dateparser.parse(x).strftime('%Y-%m-%d') if isinstance(x, str) and dateparser.parse(x) is not None else x)
# Vérifier le résultat

#new_df.sort_values(by = "Date_review", ascending= False)
# Out:
# C:\Users\yaya-\AppData\Local\Temp/ipykernel_13848/992646271.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["Date_reply"] = new_df["Date_reply"].fillna(new_df["Date_review"])
# C:\Users\yaya-\AppData\Local\Temp/ipykernel_13848/992646271.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Date_review'] = new_df['Date_review'].apply(lambda x: dateparser.parse(x).strftime('%Y-%m-%d') if isinstance(x, str) and dateparser.parse(x) is not None else x)

# %%
new_df[new_df['Date_review'].str.contains("Updated")]
# Out:
#               Company                     Customer  Number_review  \
# 71    Younited Credit                       DANIEL              3
# 327   Younited Credit                      Georges              3
# 335   Younited Credit                       Aliana              1
# 376   Younited Credit              Monsieur ISMAIL              4
# 421   Younited Credit                      Vincent              2
# 423   Younited Credit                    Dominique              1
# 426   Younited Credit                          Max              1
# 438   Younited Credit                         PAUL              5
# 447   Younited Credit                      Nicolas              3
# 462   Younited Credit                     Corinne               2
# 471   Younited Credit                   DEFOURNEAU              3
# 604   Younited Credit                      ALVAREZ              1
# 717   Younited Credit  Christian René Yves PROVOST              1
# 718   Younited Credit                     Giovanni              1
# 741           Cofidis                  Beth Peake              12
# 744           Cofidis         Anuradha Kariyawasam              1
# 986       Orange Bank                         mike              9
# 1736      Orange Bank                   Josh Casey              3
# 1751      Orange Bank                 Gary Munting             23
# 1752      Orange Bank                 Gary Munting             11
# 2061       BoursoBank               Nawazish Mirza              2
# 2104       BoursoBank                       Pierre              6
# 2191       BoursoBank               Client Guy Roy              5
# 2301       BoursoBank                        AlexO             13
#
#               Language                                              Title  \
# 71    [[[], []], [FR]]                                        SERVICE TOP
# 327   [[[], []], [FR]]                                           Younited
# 335   [[[], []], [FR]]  Younited Crédit...je recommande...dispositif s...
# 376   [[[], []], [FR]]           bon service simple et rapide det fiable.
# 421   [[[], []], [FR]]                Très contente de younited c simple…
# 423   [[[], []], [TH]]                                 Evaluation rapide.
# 426   [[[], []], [FR]]                 finncement adaptable à nos besoin.
# 438   [[[], []], [FR]]                    Very efficient and professional
# 447   [[[], []], [FR]]                                       très content
# 462   [[[], []], [FR]]                                   rapide et simple
# 471   [[[], []], [FR]]                                          Excellent
# 604   [[[], []], [FR]]  Très bon service petit probleme sur l’applicat...
# 717   [[[], []], [FR]]                                          excellent
# 718   [[[], []], [LU]]                                               Good
# 741   [[[], []], [FR]]              Very easy to sort out and cofidis do…
# 744   [[[], []], [FR]]  This isn't the right place to have even small ...
# 986   [[[], []], [FR]]                  I would not recommend Orange Bank
# 1736  [[[], []], [FR]]           Terrible in virtually every way (yes as…
# 1751  [[[], []], [FR]]                               Do not use this bank
# 1752  [[[], []], [FR]]                               ORANGE BANK NO,NO !!
# 2061  [[[], []], [AE]]       Highly unprofessional and disrespectful bank
# 2104  [[[], []], [LU]]           Boursorama claims to be an easy to deal…
# 2191  [[[], []], [FR]]                                     rien  a redire
# 2301  [[[], []], [FR]]                 We don't provide services for non…
#
#                Date_review                                              Reply  \
# 71    Updated Aug 14, 2023  Bonjour,Nous vous remercions d’avoir pris le t...
# 327   Updated Feb 11, 2021                                               None
# 335   Updated Dec 22, 2020  Bonjour Madame, Nous vous remercions pour ce c...
# 376    Updated Aug 8, 2020                                               None
# 421   Updated Jan 19, 2020                                               None
# 423    Updated Jan 9, 2020                                               None
# 426    Updated Dec 4, 2019  Bonjour Monsieur ,Nous vous remercions d’avoir...
# 438    Updated Nov 3, 2019                                               None
# 447    Updated Oct 9, 2019                                               None
# 462    Updated Aug 7, 2019                                               None
# 471    Updated Jul 4, 2019                                               None
# 604   Updated Nov 14, 2017  Bonjour Alvarez,Merci beaucoup d'avoir remonté...
# 717   Updated Oct 25, 2013                                               None
# 718   Updated Oct 11, 2013                                               None
# 741    Updated Aug 3, 2021  Je suis ravi de lire votre commentaire. Je vou...
# 744    Updated Jul 4, 2023  Bonjour Anuradha.Je vous invite à me faire par...
# 986   Updated Mar 15, 2023  Bonjour Mike, Nous sommes sincèrement navrés d...
# 1736  Updated Apr 16, 2021  Bonjour Josh Casey,Nous sommes désolés pour ce...
# 1751  Updated Jun 10, 2022  Bonjour Gary,Nous ne promettons pas de remplac...
# 1752  Updated May 13, 2022  Bonjour Gary,Je tiens à m'excuser des difficul...
# 2061   Updated Sep 9, 2022                                               None
# 2104  Updated Mar 11, 2023                                               None
# 2191  Updated Feb 25, 2022                                               None
# 2301   Updated Jun 4, 2023                                               None
#
#                 Date_reply  Rating    Status  \
# 71            Aug 14, 2023       5  Verified
# 327   Updated Feb 11, 2021       5  Verified
# 335           Dec 21, 2020       5  Verified
# 376    Updated Aug 8, 2020       5  Verified
# 421   Updated Jan 19, 2020       5  Verified
# 423    Updated Jan 9, 2020       5  Verified
# 426            Dec 4, 2019       5  Verified
# 438    Updated Nov 3, 2019       5  Verified
# 447    Updated Oct 9, 2019       4  Verified
# 462    Updated Aug 7, 2019       4  Verified
# 471    Updated Jul 4, 2019       5  Verified
# 604           Nov 14, 2017       4   Invited
# 717   Updated Oct 25, 2013       4   Invited
# 718   Updated Oct 11, 2013       5   Invited
# 741    Updated Aug 3, 2021       5   Invited
# 744           Jun 21, 2023       1   Invited
# 986           Mar 14, 2023       1   Invited
# 1736          Apr 16, 2021       1   Invited
# 1751          Jun 10, 2022       1   Invited
# 1752          May 13, 2022       1   Invited
# 2061   Updated Sep 9, 2022       1    Merged
# 2104  Updated Mar 11, 2023       2    Merged
# 2191  Updated Feb 25, 2022       5    Merged
# 2301   Updated Jun 4, 2023       1    Merged
#
#                                              Experience  \
# 71    SERVICE TOPefficacité simplicité et RAPIDITE !...
# 327      YounitedYounited - rapide simple et efficace !
# 335   Younited Crédit...je recommande...dispositif s...
# 376   bon service simple et rapide det fiable.bon se...
# 421   Très contente de younited c simple…Très conten...
# 423                                  Evaluation rapide.
# 426   finncement adaptable à nos besoin.financement ...
# 438   Very efficient and professionalVery efficient ...
# 447   très contentsimple, rapide et efficace je reco...
# 462                                    rapide et simple
# 471   ExcellentExcellent , merci à younited.Je recom...
# 604   Très bon service petit probleme sur l’applicat...
# 717              excellentexcellent excellent excellent
# 718   GoodHappy with the service. My only remarks as...
# 741   Very easy to sort out and cofidis do…Très faci...
# 744   This isn't the right place to have even small ...
# 986   I would not recommend Orange BankI would not r...
# 1736  Terrible in virtually every way (yes as…Terrib...
# 1751  Do not use this bankNearly 2 years to respond....
# 1752  ORANGE BANK NO,NO !!My advice is DO NOT open a...
# 2061  Highly unprofessional and disrespectful bankI ...
# 2104  Boursorama claims to be an easy to deal…Mise à...
# 2191  rien  a redirerien  a redire , les operations ...
# 2301  We don't provide services for non…We don't pro...
#
#                                         Date_experience
# 71                                      August 01, 2023
# 327                                   February 11, 2021
# 335                                   December 19, 2020
# 376                                     August 08, 2020
# 421                                    January 19, 2020
# 423                                    January 09, 2020
# 426                                   December 04, 2019
# 438                                   November 03, 2019
# 447                                    October 09, 2019
# 462                                     August 07, 2019
# 471                                       July 04, 2019
# 604                                   November 14, 2017
# 717                                    October 25, 2013
# 718   \r- A bit late reply to my email enquiry in En...
# 741                                     August 03, 2021
# 744                                       June 20, 2023
# 986                                      March 14, 2023
# 1736                                     April 06, 2021
# 1751                                      June 28, 2020
# 1752                                       May 14, 2019
# 2061                                 September 04, 2022
# 2104  Boursorama, non content de recevoir un avis cl...
# 2191   important !  , tout en respectant la securité...
# 2301                                     March 06, 2019

# %%
import re

# Create a regular expression to match the date format
date_regex = re.compile(r'^\d{4}-\d{2}-\d{2}$')

# Identify the invalid dates
invalid_dates = []
for date in new_df['Date_review']:
    if not date_regex.match(date):
        invalid_dates.append(date)

# Print the number of invalid dates
print(len(invalid_dates))
# Out:
# 24

# %%
min_date = min(new_df['Date_review'])
new_df['Date_review'] = new_df['Date_review'].apply(lambda x: min_date if not date_regex.match(x) else x)
# Out:
# C:\Users\yaya-\AppData\Local\Temp/ipykernel_13848/3766287997.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Date_review'] = new_df['Date_review'].apply(lambda x: min_date if not date_regex.match(x) else x)

# %%
#import datetime

# Replace the invalid dates with the current date
#for date in invalid_dates:
    #new_df['Date_review'].loc[new_df['Date_review'] == date] = datetime.date.today()

# Print the DataFrame
new_df.dtypes
# Out:
# Company            object
# Customer           object
# Number_review       int64
# Language           object
# Title              object
# Date_review        object
# Reply              object
# Date_reply         object
# Rating              int64
# Status             object
# Experience         object
# Date_experience    object
# dtype: object

# %%
import pandas as pd
import dateparser

#Convertir la colonne "Date_reply" en dates
new_df["Date_reply"] = new_df["Date_reply"].apply(lambda x: dateparser.parse(x) if isinstance(x, str) else x)
#Remplacer les valeurs manquantes de "Date_reply" par les valeurs de "Date_review"
new_df["Date_reply"] = new_df.apply(lambda row: row["Date_review"] if pd.isna(row["Date_reply"]) else row["Date_reply"], axis=1)
#Convertir la colonne "Date_reply" en dates
new_df["Date_experience"] = new_df["Date_experience"].apply(lambda x: dateparser.parse(x) if isinstance(x, str) else x)
#Remplacer les valeurs manquantes de "Date_reply" par les valeurs de "Date_review"
new_df["Date_experience"] = new_df.apply(lambda row: row["Date_experience"] if pd.isna(row["Date_experience"]) else row["Date_experience"], axis=1)
#Convertir la colonne "Date_reply" en dates
new_df["Date_review"] = new_df["Date_review"].apply(lambda x: dateparser.parse(x) if isinstance(x, str) else x)
#Remplacer les valeurs manquantes de "Date_reply" par les valeurs de "Date_review"
new_df["Date_review"] = new_df.apply(lambda row: row["Date_review"] if pd.isna(row["Date_review"]) else row["Date_review"], axis=1)

# Vérifier le résultat

#new_df.sort_values(by = "Date_review", ascending= False)
new_df.dtypes
# Out:
# C:\Users\yaya-\AppData\Local\Temp/ipykernel_13848/1703669963.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["Date_reply"] = new_df["Date_reply"].apply(lambda x: dateparser.parse(x) if isinstance(x, str) else x)
# C:\Users\yaya-\AppData\Local\Temp/ipykernel_13848/1703669963.py:7: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype={value.dtype})
#   new_df["Date_reply"] = new_df.apply(lambda row: row["Date_review"] if pd.isna(row["Date_reply"]) else row["Date_reply"], axis=1)
# C:\Users\yaya-\AppData\Local\Temp/ipykernel_13848/1703669963.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["Date_reply"] = new_df.apply(lambda row: row["Date_review"] if pd.isna(row["Date_reply"]) else row["Date_reply"], axis=1)
# C:\Users\yaya-\AppData\Local\Temp/ipykernel_13848/1703669963.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["Date_experience"] = new_df["Date_experience"].apply(lambda x: dateparser.parse(x) if isinstance(x, str) else x)
# C:\Users\yaya-\AppData\Local\Temp/ipykernel_13848/1703669963.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["Date_experience"] = new_df.apply(lambda row: row["Date_experience"] if pd.isna(row["Date_experience"]) else row["Date_experience"], axis=1)
# C:\Users\yaya-\AppData\Local\Temp/ipykernel_13848/1703669963.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["Date_review"] = new_df["Date_review"].apply(lambda x: dateparser.parse(x) if isinstance(x, str) else x)
# C:\Users\yaya-\AppData\Local\Temp/ipykernel_13848/1703669963.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["Date_review"] = new_df.apply(lambda row: row["Date_review"] if pd.isna(row["Date_review"]) else row["Date_review"], axis=1)
# Company                    object
# Customer                   object
# Number_review               int64
# Language                   object
# Title                      object
# Date_review        datetime64[ns]
# Reply                      object
# Date_reply         datetime64[ns]
# Rating                      int64
# Status                     object
# Experience                 object
# Date_experience    datetime64[ns]
# dtype: object

# %%
# Fonction de conversion personnalisée
def convert_review_date(date_str):
    try:
        parsed_date = dateparser.parse(date_str)
        if parsed_date:
            return parsed_date.strftime('%Y-%m-%d')
    except Exception:
        pass
    return date_str

# Appliquer la fonction de conversion à la colonne Date_review
new_df['Date_review'] = new_df['Date_review'].apply(convert_review_date)
#new_df["Response_time"] = new_df["Date_reply"] - new_df["Date_review"]
new_df['Date_reply'] = new_df['Date_reply'].apply(convert_review_date)

new_df
# Out:
# C:\Users\yaya-\AppData\Local\Temp/ipykernel_13848/21958708.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Date_review'] = new_df['Date_review'].apply(convert_review_date)
# C:\Users\yaya-\AppData\Local\Temp/ipykernel_13848/21958708.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Date_reply'] = new_df['Date_reply'].apply(convert_review_date)
#               Company                     Customer  Number_review  \
# 0     Younited Credit                       Alexis              2
# 1     Younited Credit                     Exo Saru              3
# 2     Younited Credit                      Getifra              3
# 3     Younited Credit                        Duval              9
# 4     Younited Credit                        Soso               2
# ...               ...                          ...            ...
# 2438          Anytime                 AMIR TAOUBAS              1
# 2439          Anytime             HOCINE TABERKOKT              1
# 2440          Anytime  TOTO JOSUE WENCESLAS KOUAME              1
# 2441          Anytime                  SHOLA SANNI              1
# 2442          Anytime                PATRICE YALAP              1
#
#               Language                                   Title Date_review  \
# 0     [[[], []], [FR]]                       Very good service  2023-10-23
# 1     [[[], []], [FR]]                            Super simple  2023-08-24
# 2     [[[], []], [FR]]         Younited Credit a démontré son…  2023-08-05
# 3     [[[], []], [FR]]  Rapide efficace simple un pur bonheur…  2022-11-28
# 4     [[[], []], [FR]]           Younited une procédure simple  2023-02-25
# ...                ...                                     ...         ...
# 2438  [[[], []], [DE]]                         Service parfait  2023-03-03
# 2439  [[[], []], [FR]]                Excellente communication  2022-05-16
# 2440  [[[], []], [FR]]                Excellent service client  2023-03-08
# 2441  [[[], []], [FR]]                 Nice job and keep it up  2022-04-11
# 2442  [[[], []], [FR]]                               excellent  2022-04-05
#
#                                                   Reply Date_reply  Rating  \
# 0     Bonjour,Nous sommes enchantés de vous lire et ... 2023-10-24       5
# 1     Bonjour,Nous vous remercions d’avoir pris le t... 2023-08-25       5
# 2     Bonjour,Nous vous remercions d’avoir pris le t... 2023-08-08       5
# 3     Bonjour,Merci d’avoir pris le temps de nous fa... 2022-11-30       5
# 4     Bonjour,Nous vous remercions pour ce commentai... 2023-02-27       5
# ...                                                 ...        ...     ...
# 2438  Bonjour 😁, Merci pour votre super avis ! A trè... 2023-03-06       5
# 2439  Bonjour 🫶, Merci beaucoup pour l'avis positif ... 2022-05-17       5
# 2440  Bonjour Toto Josue, Merci de partager votre av... 2023-03-09       5
# 2441  Bonjour 😁Merci beaucoup pour cet avis positif.... 2022-04-13       5
# 2442  Bonjour Patrice, Merci pour ce commentaire pos... 2022-04-05       5
#
#         Status                                         Experience  \
# 0     Verified                                  Very good service
# 1     Verified  Super simpleSuper simple, très rapide, interfa...
# 2     Verified  Younited Credit a démontré son…Younited Credit...
# 3     Verified  Rapide efficace simple un pur bonheur…Rapide e...
# 4     Verified  Younited une procédure simpleYounited permet u...
# ...        ...                                                ...
# 2438   Invited                                    Service parfait
# 2439   Invited                           Excellente communication
# 2440   Invited                           Excellent service client
# 2441   Invited                            Nice job and keep it up
# 2442   Invited                   excellentexcellente intervention
#
#      Date_experience
# 0         2023-10-18
# 1         2023-08-17
# 2         2023-07-27
# 3         2022-11-28
# 4         2023-02-19
# ...              ...
# 2438      2023-03-02
# 2439      2022-05-16
# 2440      2023-01-31
# 2441      2022-04-11
# 2442      2022-04-05
#
# [2443 rows x 12 columns]

# %%
#new_df["Date_reply"] = new_df["Date_reply"].fillna(new_df["Date_review"])
new_df["Response_time"] = new_df["Date_reply"] - new_df["Date_review"]
new_df.isnull().sum()
# Out:
# C:\Users\yaya-\AppData\Local\Temp/ipykernel_13848/1002915204.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["Response_time"] = new_df["Date_reply"] - new_df["Date_review"]
# Company               0
# Customer              0
# Number_review         0
# Language              3
# Title                 0
# Date_review           0
# Reply              1008
# Date_reply            0
# Rating                0
# Status                0
# Experience            0
# Date_experience      32
# Response_time         0
# dtype: int64

# %%
new_df["Response_time"]
# Out:
# 0      1 days
# 1      1 days
# 2      3 days
# 3      2 days
# 4      2 days
#         ...
# 2438   3 days
# 2439   1 days
# 2440   1 days
# 2441   2 days
# 2442   0 days
# Name: Response_time, Length: 2443, dtype: timedelta64[ns]

# %% [markdown]
# import pandas as pd
# import dateparser
#
# # Convert "Date_review" column to dates
# new_df.loc[:, "Date_review"] = new_df["Date_review"].apply(lambda x: dateparser.parse(x) if isinstance(x, str) else x)
#
# # Convert "Date_reply" column to dates
# new_df.loc[:, "Date_reply"] = new_df["Date_reply"].apply(lambda x: dateparser.parse(x) if isinstance(x, str) else x)
#
# # Convert "Date_experience" column to dates
# new_df.loc[:, "Date_experience"] = new_df["Date_experience"].apply(lambda x: dateparser.parse(x) if isinstance(x, str) else x)

# %% [markdown]
# import pandas as pd
# import dateparser
#
# Remplacer les valeurs manquantes (NaN) de la colonne "Date_reply" par celles de la colonne "Date_review"
# new_df["Date_reply"].fillna(new_df["Date_review"], inplace=True)
#
# Convertir les colonnes "Date_review", "Date_reply" et "Date_experience" en dates
# new_df["Date_review"] = new_df["Date_review"].apply(lambda x: dateparser.parse(x) if isinstance(x, str) else x)
# new_df["Date_reply"] = new_df["Date_reply"].apply(lambda x: dateparser.parse(x) if isinstance(x, str) else x)
# new_df["Date_experience"] = new_df["Date_experience"].apply(lambda x: dateparser.parse(x) if isinstance(x, str) else x)
# new_df.dtypes

# %%
new_df.isnull().sum()
# Out:
# Company               0
# Customer              0
# Number_review         0
# Language              3
# Title                 0
# Date_review           0
# Reply              1008
# Date_reply            0
# Rating                0
# Status                0
# Experience            0
# Date_experience      32
# Response_time         0
# dtype: int64

# %%
new_df[["Reply"]] = new_df[["Reply"]].fillna("No Reply")
#new_df[["Date_review", "Date_reply", "Date_experience"]] = new_df[["Date_review", "Date_reply", "Date_experience"]].fillna(0)
new_df.dtypes
# Out:
# c:\Users\yaya-\anaconda3\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# Company                     object
# Customer                    object
# Number_review                int64
# Language                    object
# Title                       object
# Date_review         datetime64[ns]
# Reply                       object
# Date_reply          datetime64[ns]
# Rating                       int64
# Status                      object
# Experience                  object
# Date_experience     datetime64[ns]
# Response_time      timedelta64[ns]
# dtype: object

# %%
#new_df = new_df.drop("Date_reply", axis = 1)
new_df = new_df.dropna(how="any")
new_df.isna().sum()
# Out:
# Company            0
# Customer           0
# Number_review      0
# Language           0
# Title              0
# Date_review        0
# Reply              0
# Date_reply         0
# Rating             0
# Status             0
# Experience         0
# Date_experience    0
# Response_time      0
# dtype: int64

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2408 entries, 0 to 2442
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company          2408 non-null   object
#  1   Customer         2408 non-null   object
#  2   Number_review    2408 non-null   int64
#  3   Language         2408 non-null   object
#  4   Title            2408 non-null   object
#  5   Date_review      2408 non-null   datetime64[ns]
#  6   Reply            2408 non-null   object
#  7   Date_reply       2408 non-null   datetime64[ns]
#  8   Rating           2408 non-null   int64
#  9   Status           2408 non-null   object
#  10  Experience       2408 non-null   object
#  11  Date_experience  2408 non-null   datetime64[ns]
#  12  Response_time    2408 non-null   timedelta64[ns]
# dtypes: datetime64[ns](3), int64(2), object(7), timedelta64[ns](1)
# memory usage: 263.4+ KB

# %%
columns_to_convert = ['Date_review', 'Date_experience', 'Date_reply']

for col in columns_to_convert:
    new_df[col] = pd.to_datetime(new_df[col]).dt.strftime('%Y-%m-%d')
# Out:
# C:\Users\yaya-\AppData\Local\Temp/ipykernel_13848/1252918539.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df[col] = pd.to_datetime(new_df[col]).dt.strftime('%Y-%m-%d')
# C:\Users\yaya-\AppData\Local\Temp/ipykernel_13848/1252918539.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df[col] = pd.to_datetime(new_df[col]).dt.strftime('%Y-%m-%d')
# C:\Users\yaya-\AppData\Local\Temp/ipykernel_13848/1252918539.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df[col] = pd.to_datetime(new_df[col]).dt.strftime('%Y-%m-%d')

# %%
new_df.dtypes
# Out:
# Company                     object
# Customer                    object
# Number_review                int64
# Language                    object
# Title                       object
# Date_review                 object
# Reply                       object
# Date_reply                  object
# Rating                       int64
# Status                      object
# Experience                  object
# Date_experience             object
# Response_time      timedelta64[ns]
# dtype: object

# %%
new_df["Response_time"] = new_df["Response_time"].astype(str)
new_df[["Response_time", "Day"]] = new_df["Response_time"].str.split(" ", n=1, expand=True)
new_df = new_df.drop("Day", axis=1)
new_df
# Out:
# C:\Users\yaya-\AppData\Local\Temp/ipykernel_13848/215425970.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["Response_time"] = new_df["Response_time"].astype(str)
# c:\Users\yaya-\anaconda3\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#               Company                     Customer  Number_review  \
# 0     Younited Credit                       Alexis              2
# 1     Younited Credit                     Exo Saru              3
# 2     Younited Credit                      Getifra              3
# 3     Younited Credit                        Duval              9
# 4     Younited Credit                        Soso               2
# ...               ...                          ...            ...
# 2438          Anytime                 AMIR TAOUBAS              1
# 2439          Anytime             HOCINE TABERKOKT              1
# 2440          Anytime  TOTO JOSUE WENCESLAS KOUAME              1
# 2441          Anytime                  SHOLA SANNI              1
# 2442          Anytime                PATRICE YALAP              1
#
#               Language                                   Title Date_review  \
# 0     [[[], []], [FR]]                       Very good service  2023-10-23
# 1     [[[], []], [FR]]                            Super simple  2023-08-24
# 2     [[[], []], [FR]]         Younited Credit a démontré son…  2023-08-05
# 3     [[[], []], [FR]]  Rapide efficace simple un pur bonheur…  2022-11-28
# 4     [[[], []], [FR]]           Younited une procédure simple  2023-02-25
# ...                ...                                     ...         ...
# 2438  [[[], []], [DE]]                         Service parfait  2023-03-03
# 2439  [[[], []], [FR]]                Excellente communication  2022-05-16
# 2440  [[[], []], [FR]]                Excellent service client  2023-03-08
# 2441  [[[], []], [FR]]                 Nice job and keep it up  2022-04-11
# 2442  [[[], []], [FR]]                               excellent  2022-04-05
#
#                                                   Reply  Date_reply  Rating  \
# 0     Bonjour,Nous sommes enchantés de vous lire et ...  2023-10-24       5
# 1     Bonjour,Nous vous remercions d’avoir pris le t...  2023-08-25       5
# 2     Bonjour,Nous vous remercions d’avoir pris le t...  2023-08-08       5
# 3     Bonjour,Merci d’avoir pris le temps de nous fa...  2022-11-30       5
# 4     Bonjour,Nous vous remercions pour ce commentai...  2023-02-27       5
# ...                                                 ...         ...     ...
# 2438  Bonjour 😁, Merci pour votre super avis ! A trè...  2023-03-06       5
# 2439  Bonjour 🫶, Merci beaucoup pour l'avis positif ...  2022-05-17       5
# 2440  Bonjour Toto Josue, Merci de partager votre av...  2023-03-09       5
# 2441  Bonjour 😁Merci beaucoup pour cet avis positif....  2022-04-13       5
# 2442  Bonjour Patrice, Merci pour ce commentaire pos...  2022-04-05       5
#
#         Status                                         Experience  \
# 0     Verified                                  Very good service
# 1     Verified  Super simpleSuper simple, très rapide, interfa...
# 2     Verified  Younited Credit a démontré son…Younited Credit...
# 3     Verified  Rapide efficace simple un pur bonheur…Rapide e...
# 4     Verified  Younited une procédure simpleYounited permet u...
# ...        ...                                                ...
# 2438   Invited                                    Service parfait
# 2439   Invited                           Excellente communication
# 2440   Invited                           Excellent service client
# 2441   Invited                            Nice job and keep it up
# 2442   Invited                   excellentexcellente intervention
#
#      Date_experience Response_time
# 0         2023-10-18             1
# 1         2023-08-17             1
# 2         2023-07-27             3
# 3         2022-11-28             2
# 4         2023-02-19             2
# ...              ...           ...
# 2438      2023-03-02             3
# 2439      2022-05-16             1
# 2440      2023-01-31             1
# 2441      2022-04-11             2
# 2442      2022-04-05             0
#
# [2408 rows x 13 columns]

# %%
new_df.sort_values(by = "Response_time", ascending=False)
# Out:
#               Company       Customer  Number_review          Language  \
# 1329      Orange Bank       Barbotv               3  [[[], []], [FR]]
# 252   Younited Credit       isabelle             10  [[[], []], [FR]]
# 1145      Orange Bank        Fabrice              1  [[[], []], [RE]]
# 1116      Orange Bank    Bruno Thore              2  [[[], []], [FR]]
# 1072      Orange Bank       Benjamin              1  [[[], []], [FR]]
# ...               ...            ...            ...               ...
# 935           Cofidis        PRANGER              6  [[[], []], [FR]]
# 934           Cofidis         MAJDA               1  [[[], []], [FR]]
# 933           Cofidis         Boubou              1  [[[], []], [FR]]
# 932           Cofidis             LL              3  [[[], []], [FR]]
# 2442          Anytime  PATRICE YALAP              1  [[[], []], [FR]]
#
#                                       Title Date_review  \
# 1329                                 Simple  2022-05-25
# 252            Simple  rapide  et efficace.  2022-01-22
# 1145                        Service parfait  2022-09-13
# 1116                Très Bon Relationnel  .  2022-09-13
# 1072                     Simple et efficace  2023-01-09
# ...                                     ...         ...
# 935                                  Rapide  2021-04-26
# 934                                 Parfait  2021-04-26
# 933                                   Super  2021-04-27
# 932   Interlocuteurs professionnels et a l…  2021-05-11
# 2442                              excellent  2022-04-05
#
#                                                   Reply  Date_reply  Rating  \
# 1329  Bonjour,Parfait alors !L’objectif principale e...  2022-06-03       5
# 252   Bonjour  Madame, Nous vous remercions pour ce ...  2022-01-31       5
# 1145  Bonjour Fabrice,Nous nous efforçons d’offrir à...  2022-09-22       5
# 1116  Bonjour Bruno,Merci de souligner la qualité de...  2022-09-22       5
# 1072  Bonjour Benjamin, Merci pour ce joli retour ét...  2023-01-18       5
# ...                                                 ...         ...     ...
# 935   Bonjour Pranger et merci pour vos étoiles. Vot...  2021-04-26       5
# 934   Bonjour Majda et merci pour ces étoiles. Je n'...  2021-04-26       5
# 933   Bonsoir, merci pour votre commentaire et votre...  2021-04-27       5
# 932   Bonjour LL ! Votre satisfaction, c'est notre m...  2021-05-11       5
# 2442  Bonjour Patrice, Merci pour ce commentaire pos...  2022-04-05       5
#
#         Status                                         Experience  \
# 1329   Invited  SimpleSimple, efficace, peu de bug. Correspond...
# 252   Verified                       Simple  rapide  et efficace.
# 1145   Invited                                    Service parfait
# 1116   Invited                            Très Bon Relationnel  .
# 1072   Invited   Simple et efficaceSimple et efficace, parfait !!
# ...        ...                                                ...
# 935    Invited                 RapideRapide, simple et efficace !
# 934    Invited        Parfait,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 933    Invited                                  SuperSuper. Merci
# 932    Invited  Interlocuteurs professionnels et a l…Interlocu...
# 2442   Invited                   excellentexcellente intervention
#
#      Date_experience Response_time
# 1329      2022-05-25             9
# 252       2022-01-22             9
# 1145      2022-09-13             9
# 1116      2022-09-13             9
# 1072      2023-01-08             9
# ...              ...           ...
# 935       2021-04-26             0
# 934       2021-04-26             0
# 933       2021-04-27             0
# 932       2021-05-05             0
# 2442      2022-04-05             0
#
# [2408 rows x 13 columns]

# %%
#new_df["Date_reply"] = new_df["Date_reply"].fillna(new_df["Date_review"])
new_df.isnull().sum()
new_df["Response_time"] = new_df["Response_time"].astype('int64')

# Calculer le temps de réponse moyen pour chaque entreprise
average_response_time_by_company = new_df.groupby('Company')['Response_time'].mean()

# Afficher le résultat
average_response_time_by_company
# Out:
# Company
# Anytime             1.897810
# BoursoBank          0.000000
# Cofidis            15.192913
# Floabank            0.622222
# Orange Bank        26.101036
# Younited Credit    14.384615
# Name: Response_time, dtype: float64

# %%
new_df.to_csv("../data/processed/avis_clients.csv")

# %%
new_df.isna().sum()
# Out:
# Company            0
# Customer           0
# Number_review      0
# Language           0
# Title              0
# Date_review        0
# Reply              0
# Date_reply         0
# Rating             0
# Status             0
# Experience         0
# Date_experience    0
# Response_time      0
# dtype: int64

# %%
import pandas as pd
df_test = pd.read_csv("../data/processed/reviews.csv", )
#df_test = df_test[["Company", "Customer", "Number_review", "Language", "Title", "Date_review", "Reply", "Date_reply", "Rating", "Status", "Experience", "Date_experience", "Response_time"]]
df_test.sort_values(by="Response_time", ascending=True)
# Out:
#               Company                     Customer  Number_review Language  \
# 714   Younited Credit  Christian René Yves PROVOST              1       FR
# 713   Younited Credit                     Frederic              1       FR
# 712   Younited Credit                       Pascal              1       FR
# 711   Younited Credit             CHANTAL LAGRANGE              1       FR
# 710   Younited Credit                         alex              1       FR
# ...               ...                          ...            ...      ...
# 1839       BoursoBank                       Gilles              6       FR
# 715           Cofidis                          P.r              1       FR
# 1845       BoursoBank              Thierry MARIET;              3       FR
# 1862       BoursoBank                      Anaïs S              1       FR
# 1832       BoursoBank                    Patrick V              1       FR
#
#                    Title Date_review  \
# 714            excellent  2013-10-25
# 713             super!!!  2013-12-03
# 712          SANS SOUCIS  2014-11-20
# 711   TRES BONNE OPINION  2015-03-19
# 710            Excellent  2015-07-09
# ...                  ...         ...
# 1839    Simple et rapide  2023-11-21
# 715    Un credit parfait  2023-11-20
# 1845              Nickel  2023-11-24
# 1862   Super application  2023-11-25
# 1832    Simple et rapide  2023-11-25
#
#                                                   Reply  Date_reply  Rating  \
# 714                                            No Reply  2013-10-25       4
# 713                                            No Reply  2013-12-03       5
# 712                                            No Reply  2014-11-20       5
# 711                                            No Reply  2015-03-19       5
# 710                                            No Reply  2015-07-09       5
# ...                                                 ...         ...     ...
# 1839                                           No Reply  2023-11-21       5
# 715   Bonjour Priscilla, Merci, ça fait vraiment pla...  2023-11-21       5
# 1845                                           No Reply  2023-11-24       5
# 1862                                           No Reply  2023-11-25       5
# 1832                                           No Reply  2023-11-25       5
#
#         Status                                         Experience  \
# 714    Invited             excellentexcellent excellent excellent
# 713    Invited  super!!!très bon placement pour la diversifica...
# 712   Verified         SANS SOUCISSERVICE IMPECCABLE\rCLAIRE\rNET
# 711   Verified                    TRES BONNE OPINIONA RECOMMENDER
# 710   Verified                             ExcellentExcellent !!!
# ...        ...                                                ...
# 1839   Invited                                   Simple et rapide
# 715    Invited  Un credit parfaitUne reponse de principe immed...
# 1845   Invited  Nickelrien a reprocher, double authentificatio...
# 1862   Invited                                  Super application
# 1832   Invited                                   Simple et rapide
#
#      Date_experience  Response_time
# 714       2013-10-25             14
# 713       2013-12-03             53
# 712       2014-11-20            405
# 711       2015-03-19            524
# 710       2015-07-09            636
# ...              ...            ...
# 1839      2023-11-21           3693
# 715       2023-11-01           3693
# 1845      2023-11-24           3696
# 1862      2023-11-23           3697
# 1832      2023-11-25           3697
#
# [2530 rows x 13 columns]

# %%
df_test.isna().sum()
# Out:
# Company            0
# Customer           0
# Number_review      0
# Language           0
# Title              0
# Date_review        0
# Reply              0
# Date_reply         0
# Rating             0
# Status             0
# Experience         0
# Date_experience    0
# Response_time      0
# dtype: int64

# %%
df_test.isnull().sum()
df_test["Response_time"] = df_test["Response_time"].astype('int64')

# Calculer le temps de réponse moyen pour chaque entreprise
average_response_time_by_company_test = df_test.groupby('Company')['Response_time'].mean()

# Afficher le résultat
average_response_time_by_company_test
# Out:
# Company
# Anytime            2983.636719
# BoursoBank         3269.240909
# Cofidis            3028.350394
# Floabank           3056.266667
# Orange Bank        3188.831606
# Younited Credit    2460.071329
# Name: Response_time, dtype: float64

# %%
#df_test.isna().sum()
df_test.groupby('Status').count()
# Out:
#             Company  Customer  Number_review  Language  Title  Date_review  \
# Status
# Invited        1509      1509           1509      1509   1509         1509
# Merged          455       455            455       455    455          455
# Redirected       18        18             18        18     18           18
# Verified        545       545            545       545    545          545
#
#             Reply  Date_reply  Rating  Experience  Date_experience  \
# Status
# Invited      1509        1509    1509        1509             1509
# Merged        455         455     455         455              455
# Redirected     18          18      18          18               18
# Verified      545         545     545         545              545
#
#             Response_time
# Status
# Invited              1509
# Merged                455
# Redirected             18
# Verified              545
